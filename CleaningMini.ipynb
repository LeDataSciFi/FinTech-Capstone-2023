# %%
# #From chatGPT 
# #
# import pandas as pd
# import csv

# def clean_hmda_csv(file_path):
#     # Open the csv file in read mode and create a reader object
#     with open(file_path, 'r') as csv_file:
#         reader = csv.reader(csv_file)
        
#         # Get the header row
#         header = next(reader)
        
#         # Create a list to store the cleaned data
#         cleaned_data = []
        
#         # Loop over the remaining rows in the file
#         for row in reader:
#             # Skip the row if it has less than 50000 columns
#             if len(row) < 50000:
#                 continue
                
#             # Clean each column in the row
#             cleaned_row = [clean_column(col) for col in row]
            
#             # Add the cleaned row to the cleaned_data list
#             cleaned_data.append(cleaned_row)
            
#     # Write the cleaned data to a new csv file
#     with open('cleaned_hmda.csv', 'w', newline='') as csv_file:
#         writer = csv.writer(csv_file)
        
#         # Write the header row
#         writer.writerow(header)
        
#         # Write the cleaned data
#         writer.writerows(cleaned_data)
        
# def clean_column(col):
#     # Code to clean the data in the column
#     # For example:
#     # Remove leading and trailing whitespaces
#     return col.strip()

# hmda_clean = clean_hmda_csv('./input_data/state_AZ-CA_mini.csv')
# hmda_clean.type()
# #hmda_cleanDF = pd.read_csv(hmda_clean)
# #hmda_clean.to_csv('./data/hmdaclean.csv')

import pandas as pd

def clean_hmda_csv(file_path):
    # Load the csv file into a pandas DataFrame
    df = pd.read_csv(file_path)
    
    # Remove leading and trailing whitespaces from each column
    df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)
    
    return df

hmdadf = clean_hmda_csv('./input_data/state_AZ-CA_mini.csv')
hmdadf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 99 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   activity_year                             50000 non-null  int64
#  1   lei                                       50000 non-null  object
#  2   derived_msa-md                            50000 non-null  int64
#  3   state_code                                50000 non-null  object
#  4   county_code                               49821 non-null  float64
#  5   census_tract                              49783 non-null  float64
#  6   conforming_loan_limit                     49809 non-null  object
#  7   derived_loan_product_type                 50000 non-null  object
#  8   derived_dwelling_category                 50000 non-null  object
#  9   derived_ethnicity                         50000 non-null  object
# ...
