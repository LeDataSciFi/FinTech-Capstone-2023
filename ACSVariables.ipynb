# %%
# Attempting to select the ACS variables we will need to carry out the appropriate analysis

# %%
import pandas as pd

# %%
# Loading cenpy and acs data
import cenpy
acs = cenpy.products.ACS(2019)

# %%
groupedVars = acs.tables

# %%
varList = []

# %%
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_columns', 30)

# %%
# exploring race tables
acs.filter_tables("RACE", by = "description")
# Out:
#                                                   description  \
# table_name
# B02001                                                   RACE
# B02008      WHITE ALONE OR IN COMBINATION WITH ONE OR MORE...
# B02009      BLACK OR AFRICAN AMERICAN ALONE OR IN COMBINAT...
# B02010      AMERICAN INDIAN AND ALASKA NATIVE ALONE OR IN ...
# B02011      ASIAN ALONE OR IN COMBINATION WITH ONE OR MORE...
# B02012      NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALO...
# B02013      SOME OTHER RACE ALONE OR IN COMBINATION WITH O...
# B03002                      HISPANIC OR LATINO ORIGIN BY RACE
# B25006                                    RACE OF HOUSEHOLDER
# B98013      TOTAL POPULATION COVERAGE RATE BY WEIGHTING RA...
# B99021                                     ALLOCATION OF RACE
# C02003                                          DETAILED RACE
#
#                                                       columns
# table_name
# B02001      [B02001_001E, B02001_002E, B02001_003E, B02001...
# ...

# %%
# Exploring the race table
acs.filter_variables("B02001")
# Out:
#                                                          label concept  \
# B02001_009E  Estimate!!Total:!!Two or more races:!!Two race...    RACE
# B02001_007E            Estimate!!Total:!!Some other race alone    RACE
# B02001_008E               Estimate!!Total:!!Two or more races:    RACE
# B02001_010E  Estimate!!Total:!!Two or more races:!!Two race...    RACE
# B02001_002E                      Estimate!!Total:!!White alone    RACE
# B02001_001E                                   Estimate!!Total:    RACE
# B02001_006E  Estimate!!Total:!!Native Hawaiian and Other Pa...    RACE
# B02001_005E                      Estimate!!Total:!!Asian alone    RACE
# B02001_004E  Estimate!!Total:!!American Indian and Alaska N...    RACE
# B02001_003E  Estimate!!Total:!!Black or African American alone    RACE
#
#             predicateType   group limit predicateOnly hasGeoCollectionSupport  \
# B02001_009E           int  B02001     0           NaN                     NaN
# ...

# %%
list1 = ["B02001_001E", "B02001_002E", "B02001_003E", "B02001_004E", "B02001_005E", "B02001_006E", "B02001_007E", "B02001_008E", "B02001_009E", "B02001_010E"]

# %%
varList.extend(list1)

# %%
# Exploring the hispanic table
acs.filter_variables("B03002")
# Out:
#                                                          label  \
# B03002_021E  Estimate!!Total:!!Hispanic or Latino:!!Two or ...
# B03002_020E  Estimate!!Total:!!Hispanic or Latino:!!Two or ...
# B03002_001E                                   Estimate!!Total:
# B03002_005E  Estimate!!Total:!!Not Hispanic or Latino:!!Ame...
# B03002_004E  Estimate!!Total:!!Not Hispanic or Latino:!!Bla...
# B03002_003E  Estimate!!Total:!!Not Hispanic or Latino:!!Whi...
# B03002_002E          Estimate!!Total:!!Not Hispanic or Latino:
# B03002_009E  Estimate!!Total:!!Not Hispanic or Latino:!!Two...
# B03002_007E  Estimate!!Total:!!Not Hispanic or Latino:!!Nat...
# B03002_008E  Estimate!!Total:!!Not Hispanic or Latino:!!Som...
# B03002_006E  Estimate!!Total:!!Not Hispanic or Latino:!!Asi...
# B03002_013E  Estimate!!Total:!!Hispanic or Latino:!!White a...
# B03002_012E              Estimate!!Total:!!Hispanic or Latino:
# B03002_011E  Estimate!!Total:!!Not Hispanic or Latino:!!Two...
# ...

# %%
list2 = ['B03002_001','B03002_002','B03002_012']

# %%
varList.extend(list2)

# %%
# Exploring race of householder table
acs.filter_variables("B25006")
# Out:
#                                                          label  \
# B25006_007E  Estimate!!Total:!!Householder who is Some othe...
# B25006_008E  Estimate!!Total:!!Householder who is Two or mo...
# B25006_005E   Estimate!!Total:!!Householder who is Asian alone
# B25006_006E  Estimate!!Total:!!Householder who is Native Ha...
# B25006_009E  Estimate!!Total:!!Householder who is Two or mo...
# B25006_002E   Estimate!!Total:!!Householder who is White alone
# B25006_004E  Estimate!!Total:!!Householder who is American ...
# B25006_003E  Estimate!!Total:!!Householder who is Black or ...
# B25006_001E                                   Estimate!!Total:
# B25006_010E  Estimate!!Total:!!Householder who is Two or mo...
#
#                          concept predicateType   group limit predicateOnly  \
# B25006_007E  RACE OF HOUSEHOLDER           int  B25006     0           NaN
# B25006_008E  RACE OF HOUSEHOLDER           int  B25006     0           NaN
# ...

# %%
list3 = ['B25006_001E', 'B25006_002E', 'B25006_003E', 'B25006_004E', 'B25006_005E', 'B25006_006E', 'B25006_007E', 'B25006_008E', 'B25006_009E', 'B25006_010E']

# %%
varList.extend(list3)

# %%
# Exploring the income tables
acs.filter_tables("INCOME", by = "description")#ts
# Out:
#                                                   description  \
# table_name
# B05010      RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 1...
# B06010      PLACE OF BIRTH BY INDIVIDUAL INCOME IN THE PAS...
# B06011      MEDIAN INCOME IN THE PAST 12 MONTHS (IN 2019 I...
# B07010      GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY INDI...
# B07011      MEDIAN INCOME IN THE PAST 12 MONTHS (IN 2019 I...
# ...                                                       ...
# C17002      RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 1...
# C18131      RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 1...
# C27016      HEALTH INSURANCE COVERAGE STATUS BY RATIO OF I...
# C27017      PRIVATE HEALTH INSURANCE BY RATIO OF INCOME TO...
# C27018      PUBLIC HEALTH INSURANCE BY RATIO OF INCOME TO ...
#
#                                                       columns
# table_name
# B05010      [B05010_001E, B05010_002E, B05010_003E, B05010...
# B06010      [B06010_001E, B06010_002E, B06010_003E, B06010...
# ...

# %%
incomeTables = ["B19001", "B19013", "C17002", "B25098", "B25099", "B25071", "B25070", "B19313", "B19301", "B19113", "B19101", "B19062"]

# %%
# Inspecting income table variables

# %%
acs.filter_variables("B19001")
# Out:
#                                                label  \
# B19001B_014E  Estimate!!Total:!!$100,000 to $124,999
# B19001B_013E    Estimate!!Total:!!$75,000 to $99,999
# B19001B_012E    Estimate!!Total:!!$60,000 to $74,999
# B19001B_011E    Estimate!!Total:!!$50,000 to $59,999
# B19001B_010E    Estimate!!Total:!!$45,000 to $49,999
# ...                                              ...
# B19001E_013E    Estimate!!Total:!!$75,000 to $99,999
# B19001E_014E  Estimate!!Total:!!$100,000 to $124,999
# B19001E_015E  Estimate!!Total:!!$125,000 to $149,999
# B19001E_016E  Estimate!!Total:!!$150,000 to $199,999
# B19001E_017E      Estimate!!Total:!!$200,000 or more
#
#                                                         concept predicateType  \
# B19001B_014E  HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN


# %%
incomeTables
# Out:
# ['B19001',
#  'B19013',
#  'C17002',
#  'B25098',
#  'B25099',
#  'B25071',
#  'B25070',
#  'B19313',
#  'B19301',
#  'B19113',
#  'B19101',
#  'B19062']

# %%
acs.filter_variables("C17002")
# Out:
#                                        label  \
# C17002_002E      Estimate!!Total:!!Under .50
# C17002_001E                 Estimate!!Total:
# C17002_008E  Estimate!!Total:!!2.00 and over
# C17002_007E   Estimate!!Total:!!1.85 to 1.99
# C17002_004E   Estimate!!Total:!!1.00 to 1.24
# C17002_003E     Estimate!!Total:!!.50 to .99
# C17002_006E   Estimate!!Total:!!1.50 to 1.84
# C17002_005E   Estimate!!Total:!!1.25 to 1.49
#
#                                                        concept predicateType  \
# C17002_002E  RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 1...           int
# C17002_001E  RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 1...           int
# C17002_008E  RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 1...           int
# C17002_007E  RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 1...           int
# C17002_004E  RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 1...           int
# C17002_003E  RATIO OF INCOME TO POVERTY LEVEL IN THE PAST 1...           int
# ...

# %%
list6 = ["C17002_001E", "C17002_002E", "C17002_003E", "C17002_004E", "C17002_005E", "C17002_006E", "C17002_007E", "C17002_008E"]

# %%
varList.extend(list6)

# %%
incomeTables
# Out:
# ['B19001',
#  'B19013',
#  'C17002',
#  'B25098',
#  'B25099',
#  'B25071',
#  'B25070',
#  'B19313',
#  'B19301',
#  'B19113',
#  'B19101',
#  'B19062']

# %%
acs.filter_variables("B25098")
# Out:
#                                                          label  \
# B25098_018E  Estimate!!Total:!!Not mortgaged:!!$100,000 to ...
# B25098_019E  Estimate!!Total:!!Not mortgaged:!!$150,000 or ...
# B25098_016E  Estimate!!Total:!!Not mortgaged:!!$50,000 to $...
# B25098_017E  Estimate!!Total:!!Not mortgaged:!!$75,000 to $...
# B25098_014E  Estimate!!Total:!!Not mortgaged:!!$25,000 to $...
# B25098_015E  Estimate!!Total:!!Not mortgaged:!!$35,000 to $...
# B25098_012E  Estimate!!Total:!!Not mortgaged:!!Less than $1...
# B25098_013E  Estimate!!Total:!!Not mortgaged:!!$10,000 to $...
# B25098_008E  Estimate!!Total:!!With a mortgage:!!$75,000 to...
# B25098_009E  Estimate!!Total:!!With a mortgage:!!$100,000 t...
# B25098_006E  Estimate!!Total:!!With a mortgage:!!$35,000 to...
# B25098_007E  Estimate!!Total:!!With a mortgage:!!$50,000 to...
# B25098_004E  Estimate!!Total:!!With a mortgage:!!$10,000 to...
# B25098_005E  Estimate!!Total:!!With a mortgage:!!$25,000 to...
# ...

# %%
list7 = ["B25098_001E", "B25098_002E", "B25098_003E", "B25098_004E", "B25098_005E", "B25098_006E", "B25098_007E", "B25098_008E", "B25098_009E", "B25098_010E", "B25098_011E", "B25098_012E", "B25098_013E", "B25098_014E", "B25098_015E", "B25098_016E", "B25098_017E", "B25098_018E", "B25098_019E"]

# %%
varList.extend(list7)

# %%
incomeTables
# Out:
# ['B19001',
#  'B19013',
#  'C17002',
#  'B25098',
#  'B25099',
#  'B25071',
#  'B25070',
#  'B19313',
#  'B19301',
#  'B19113',
#  'B19101',
#  'B19062']

# %%
acs.filter_variables("B25099")
# Out:
#                                                          label  \
# B25099_003E  Estimate!!Median household income --!!Total:!!...
# B25099_001E       Estimate!!Median household income --!!Total:
# B25099_002E  Estimate!!Median household income --!!Total:!!...
#
#                                                        concept predicateType  \
# B25099_003E  MORTGAGE STATUS BY MEDIAN HOUSEHOLD INCOME IN ...           int
# B25099_001E  MORTGAGE STATUS BY MEDIAN HOUSEHOLD INCOME IN ...           int
# B25099_002E  MORTGAGE STATUS BY MEDIAN HOUSEHOLD INCOME IN ...           int
#
#               group limit predicateOnly hasGeoCollectionSupport  \
# B25099_003E  B25099     0           NaN                     NaN
# B25099_001E  B25099     0           NaN                     NaN
# B25099_002E  B25099     0           NaN                     NaN
#
#                                         attributes required
# B25099_003E  B25099_003EA,B25099_003M,B25099_003MA      NaN
# ...

# %%
list8 = ["B25099_001E", "B25099_002E", "B25099_003E"]

# %%
varList.extend(list8)

# %%
incomeTables
# Out:
# ['B19001',
#  'B19013',
#  'C17002',
#  'B25098',
#  'B25099',
#  'B25071',
#  'B25070',
#  'B19313',
#  'B19301',
#  'B19113',
#  'B19101',
#  'B19062']

# %%
acs.filter_variables("B25071")
# Out:
#                                                          label  \
# B25071_001E  Estimate!!Median gross rent as a percentage of...
#
#                                                        concept predicateType  \
# B25071_001E  MEDIAN GROSS RENT AS A PERCENTAGE OF HOUSEHOLD...         float
#
#               group limit predicateOnly hasGeoCollectionSupport  \
# B25071_001E  B25071     0           NaN                     NaN
#
#                                         attributes required
# B25071_001E  B25071_001EA,B25071_001M,B25071_001MA      NaN

# %%
list9 = ["B25071_001E"]

# %%
varList.extend(list9)

# %%
acs.filter_variables("B25070")
# Out:
#                                                 label  \
# B25070_003E    Estimate!!Total:!!10.0 to 14.9 percent
# B25070_002E  Estimate!!Total:!!Less than 10.0 percent
# B25070_001E                          Estimate!!Total:
# B25070_007E    Estimate!!Total:!!30.0 to 34.9 percent
# B25070_006E    Estimate!!Total:!!25.0 to 29.9 percent
# B25070_005E    Estimate!!Total:!!20.0 to 24.9 percent
# B25070_004E    Estimate!!Total:!!15.0 to 19.9 percent
# B25070_009E    Estimate!!Total:!!40.0 to 49.9 percent
# B25070_008E    Estimate!!Total:!!35.0 to 39.9 percent
# B25070_011E            Estimate!!Total:!!Not computed
# B25070_010E    Estimate!!Total:!!50.0 percent or more
#
#                                                        concept predicateType  \
# B25070_003E  GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME...           int
# B25070_002E  GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME...           int
# B25070_001E  GROSS RENT AS A PERCENTAGE OF HOUSEHOLD INCOME...           int
# ...

# %%
list10 = ["B25070_001E", "B25070_002E", "B25070_003E", "B25070_004E", "B25070_005E", "B25070_006E", "B25070_007E", "B25070_008E", "B25070_009E", "B25070_010E", "B25070_011E"]

# %%
varList.extend(list10)

# %%
incomeTables
# Out:
# ['B19001',
#  'B19013',
#  'C17002',
#  'B25098',
#  'B25099',
#  'B25071',
#  'B25070',
#  'B19313',
#  'B19301',
#  'B19113',
#  'B19101',
#  'B19062']

# %%
acs.filter_variables("B19313")
# Out:
#                                                           label  \
# B19313C_001E  Estimate!!Aggregate income in the past 12 mont...
# B19313H_001E  Estimate!!Aggregate income in the past 12 mont...
# B19313D_001E  Estimate!!Aggregate income in the past 12 mont...
# B19313I_001E  Estimate!!Aggregate income in the past 12 mont...
# B19313E_001E  Estimate!!Aggregate income in the past 12 mont...
# B19313A_001E  Estimate!!Aggregate income in the past 12 mont...
# B19313F_001E  Estimate!!Aggregate income in the past 12 mont...
# B19313_001E   Estimate!!Aggregate income in the past 12 mont...
# B19313G_001E  Estimate!!Aggregate income in the past 12 mont...
# B19313B_001E  Estimate!!Aggregate income in the past 12 mont...
#
#                                                         concept predicateType  \
# B19313C_001E  AGGREGATE INCOME IN THE PAST 12 MONTHS (IN 201...           int
# B19313H_001E  AGGREGATE INCOME IN THE PAST 12 MONTHS (IN 201...           int
# ...

# %%
list11 = ["B19313_001E", "B19313A_001E", "B19313B_001E", "B19313C_001E", "B19313D_001E", "B19313E_001E", "B19313F_001E", "B19313G_001E", "B19313H_001E", "B19313I_001E"]

# %%
varList.extend(list11)

# %%
# Exploring age tables
acs.filter_tables("AGE", by = "description")
# Out:
#                                                   description  \
# table_name
# B01001                                             SEX BY AGE
# B01002                                      MEDIAN AGE BY SEX
# B05003          SEX BY AGE BY NATIVITY AND CITIZENSHIP STATUS
# B05004      MEDIAN AGE BY NATIVITY AND CITIZENSHIP STATUS ...
# B05009      AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEAR...
# B05013             SEX BY AGE FOR THE FOREIGN-BORN POPULATION
# B05014             SEX BY AGE FOR THE FOREIGN-BORN POPULATION
# B06001             PLACE OF BIRTH BY AGE IN THE UNITED STATES
# B06002      MEDIAN AGE BY PLACE OF BIRTH IN THE UNITED STATES
# B06007      PLACE OF BIRTH BY LANGUAGE SPOKEN AT HOME AND ...
# B07001      GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE ...
# B07002      MEDIAN AGE BY GEOGRAPHICAL MOBILITY IN THE PAS...
# B07401      GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE ...
# B07402      MEDIAN AGE BY GEOGRAPHICAL MOBILITY IN THE PAS...
# ...

# %%
incomeTables
# Out:
# ['B19001',
#  'B19013',
#  'C17002',
#  'B25098',
#  'B25099',
#  'B25071',
#  'B25070',
#  'B19313',
#  'B19301',
#  'B19113',
#  'B19101',
#  'B19062']

# %%
acs.filter_variables("B19301")
# Out:
#                                                           label  \
# B19301E_001E  Estimate!!Per capita income in the past 12 mon...
# B19301A_001E  Estimate!!Per capita income in the past 12 mon...
# B19301F_001E  Estimate!!Per capita income in the past 12 mon...
# B19301B_001E  Estimate!!Per capita income in the past 12 mon...
# B19301C_001E  Estimate!!Per capita income in the past 12 mon...
# B19301G_001E  Estimate!!Per capita income in the past 12 mon...
# B19301_001E   Estimate!!Per capita income in the past 12 mon...
# B19301I_001E  Estimate!!Per capita income in the past 12 mon...
# B19301H_001E  Estimate!!Per capita income in the past 12 mon...
# B19301D_001E  Estimate!!Per capita income in the past 12 mon...
#
#                                                         concept predicateType  \
# B19301E_001E  PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 20...           int
# B19301A_001E  PER CAPITA INCOME IN THE PAST 12 MONTHS (IN 20...           int
# ...

# %%
list12 = ["B19301_001E", "B19301A_001E", "B19301B_001E", "B19301C_001E", "B19301D_001E", "B19301E_001E", "B19301F_001E", "B19301G_001E", "B19301H_001E", "B19301I_001E"]

# %%
varList.extend(list12)

# %%
incomeTables
# Out:
# ['B19001',
#  'B19013',
#  'C17002',
#  'B25098',
#  'B25099',
#  'B25071',
#  'B25070',
#  'B19313',
#  'B19301',
#  'B19113',
#  'B19101',
#  'B19062']

# %%
acs.filter_variables("B19113")
# Out:
#                                                           label  \
# B19113_001E   Estimate!!Median family income in the past 12 ...
# B19113D_001E  Estimate!!Median family income in the past 12 ...
# B19113I_001E  Estimate!!Median family income in the past 12 ...
# B19113E_001E  Estimate!!Median family income in the past 12 ...
# B19113A_001E  Estimate!!Median family income in the past 12 ...
# B19113F_001E  Estimate!!Median family income in the past 12 ...
# B19113B_001E  Estimate!!Median family income in the past 12 ...
# B19113G_001E  Estimate!!Median family income in the past 12 ...
# B19113C_001E  Estimate!!Median family income in the past 12 ...
# B19113H_001E  Estimate!!Median family income in the past 12 ...
#
#                                                         concept predicateType  \
# B19113_001E   MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN...           int
# B19113D_001E  MEDIAN FAMILY INCOME IN THE PAST 12 MONTHS (IN...           int
# ...

# %%
list13 = ["B19113_001E", "B19113A_001E", "B19113B_001E", "B19113C_001E", "B19113D_001E", "B19113E_001E", "B19113F_001E", "B19113G_001E", "B19113H_001E", "B19113I_001E"]

# %%
varList.extend(list13)

# %%
incomeTables
# Out:
# ['B19001',
#  'B19013',
#  'C17002',
#  'B25098',
#  'B25099',
#  'B25071',
#  'B25070',
#  'B19313',
#  'B19301',
#  'B19113',
#  'B19101',
#  'B19062']

# %%
acs.filter_variables("B19101")
# Out:
#                                              label  \
# B19101A_004E  Estimate!!Total:!!$15,000 to $19,999
# B19101A_005E  Estimate!!Total:!!$20,000 to $24,999
# B19101A_006E  Estimate!!Total:!!$25,000 to $29,999
# B19101A_007E  Estimate!!Total:!!$30,000 to $34,999
# B19101A_001E                      Estimate!!Total:
# ...                                            ...
# B19101E_008E  Estimate!!Total:!!$35,000 to $39,999
# B19101E_009E  Estimate!!Total:!!$40,000 to $44,999
# B19062_001E  B19062_001EA,B19062_001M,B19062_001MA      NaN

# %%
list14 = ["B19062_001E"]

# %%
varList.extend(list14)

# %%
# Exploring age tables
acs.filter_tables("AGE", by = "description")
# Out:
#                                                   description  \
# table_name
# B01001                                             SEX BY AGE
# B01002                                      MEDIAN AGE BY SEX
# B05003          SEX BY AGE BY NATIVITY AND CITIZENSHIP STATUS
# B05004      MEDIAN AGE BY NATIVITY AND CITIZENSHIP STATUS ...
# B05009      AGE AND NATIVITY OF OWN CHILDREN UNDER 18 YEAR...
# B05013             SEX BY AGE FOR THE FOREIGN-BORN POPULATION
# B05014             SEX BY AGE FOR THE FOREIGN-BORN POPULATION
# B06001             PLACE OF BIRTH BY AGE IN THE UNITED STATES
# B06002      MEDIAN AGE BY PLACE OF BIRTH IN THE UNITED STATES
# B06007      PLACE OF BIRTH BY LANGUAGE SPOKEN AT HOME AND ...
# B07001      GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE ...
# B07002      MEDIAN AGE BY GEOGRAPHICAL MOBILITY IN THE PAS...
# B07401      GEOGRAPHICAL MOBILITY IN THE PAST YEAR BY AGE ...
# B07402      MEDIAN AGE BY GEOGRAPHICAL MOBILITY IN THE PAS...
# ...

# %%
acs.filter_variables("B01001")
# Out:
#                                                      label  \
# B01001B_029E     Estimate!!Total:!!Female:!!65 to 74 years
# B01001B_027E     Estimate!!Total:!!Female:!!45 to 54 years
# B01001B_028E     Estimate!!Total:!!Female:!!55 to 64 years
# B01001B_025E     Estimate!!Total:!!Female:!!30 to 34 years
# B01001B_026E     Estimate!!Total:!!Female:!!35 to 44 years
# ...                                                    ...
# B01001E_004E         Estimate!!Total:!!Male:!!5 to 9 years
# B01001E_003E        Estimate!!Total:!!Male:!!Under 5 years
# B01001E_002E                       Estimate!!Total:!!Male:
# B01001E_030E     Estimate!!Total:!!Female:!!75 to 84 years
# B01001E_031E  Estimate!!Total:!!Female:!!85 years and over
#
#                                                         concept predicateType  \
# B01001B_029E       SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)           int
# B01001B_027E       SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)           int
# ...

# %%
original_string = "B01001_001E"
altered_strings = ["B01001_001E"]

for i in range(1, 49):
    altered_string = original_string[:7] + "{:03d}".format(i+1) + original_string[-1]
    altered_strings.append(altered_string)

# %%
varList.extend(altered_strings)

# %%
original_string = "B01001_001E"
altered_strings1 = []

for outer_count in range(9):
    for inner_count in range(31):
        altered_string = original_string[:6] + chr(65 + outer_count) + "_" + "{:03d}".format(inner_count+1) + original_string[-1]
        altered_strings1.append(altered_string)

# %%
varList.extend(altered_strings1)

# %%
acs.filter_variables("B01002")
# Out:
#                                         label  \
# B01002I_001E  Estimate!!Median age --!!Total:
# B01002I_003E  Estimate!!Median age --!!Female
# B01002I_002E    Estimate!!Median age --!!Male
# B01002D_001E  Estimate!!Median age --!!Total:
# B01002D_002E    Estimate!!Median age --!!Male
# B01002D_003E  Estimate!!Median age --!!Female
# B01002A_003E  Estimate!!Median age --!!Female
# B01002A_002E    Estimate!!Median age --!!Male
# B01002A_001E  Estimate!!Median age --!!Total:
# B01002E_002E    Estimate!!Median age --!!Male
# B01002E_003E  Estimate!!Median age --!!Female
# B01002E_001E  Estimate!!Median age --!!Total:
# B01002B_003E  Estimate!!Median age --!!Female
# B01002B_002E    Estimate!!Median age --!!Male
# B01002B_001E  Estimate!!Median age --!!Total:
# B01002G_001E  Estimate!!Median age --!!Total:
# B01002G_003E  Estimate!!Median age --!!Female
# B01002G_002E    Estimate!!Median age --!!Male
# B01002F_003E  Estimate!!Median age --!!Female
# ...

# %%
original_string1 = "B01002_001E"
altered_strings2 = []

for outer_count in range(9):
    for inner_count in range(3):
        altered_string = original_string1[:6] + chr(65 + outer_count) + "_" + "{:03d}".format(inner_count+1) + original_string1[-1]
        altered_strings2.append(altered_string)

# %%
varList.extend(altered_strings2)

# %%
list15 = ["B01002_001E", "B01002_002E", "B01002_003E"]

# %%
varList.extend(list15)

# %%
acs.filter_variables("B01003")
# Out:
#                        label           concept predicateType   group limit  \
# B01003_001E  Estimate!!Total  TOTAL POPULATION           int  B01003     0
#
#             predicateOnly hasGeoCollectionSupport  \
# B01003_001E           NaN                     NaN
#
#                                         attributes required
# B01003_001E  B01003_001EA,B01003_001M,B01003_001MA      NaN

# %%
acs.filter_tables("POPULATION", by = "description")
# Out:
#                                                   description  \
# table_name
# B01003                                       TOTAL POPULATION
# B05006      PLACE OF BIRTH FOR THE FOREIGN-BORN POPULATION...
# B05007      PLACE OF BIRTH BY YEAR OF ENTRY BY CITIZENSHIP...
# B05008      SEX BY PLACE OF BIRTH BY YEAR OF ENTRY FOR THE...
# B05013             SEX BY AGE FOR THE FOREIGN-BORN POPULATION
# ...                                                       ...
# C24030      SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPU...
# C24040      SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND ...
# C24050      INDUSTRY BY OCCUPATION FOR THE CIVILIAN  EMPLO...
# C24060      OCCUPATION BY CLASS OF WORKER FOR THE CIVILIAN...
# C24070      INDUSTRY BY CLASS OF WORKER FOR THE CIVILIAN E...
#
#                                                       columns
# table_name
# B01003                                          [B01003_001E]
# B05006      [B05006_001E, B05006_002E, B05006_003E, B05006...
# ...

# %%
varList.append("B01003_001E")

# %%
len(varList)
# Out:
# 669

# %%
diffVars = acs.variables

# %%
diffVars = diffVars.reset_index()

# %%
diffVars.rename(columns = {"index": "VariableCode"}, inplace=True)

# %%
diffVars
# Out:
#        VariableCode                                       label  \
# 0            AIANHH                                   Geography
# 1            AIHHTL                                   Geography
# 2             AIRES                                   Geography
# 3              ANRC                                   Geography
# 4      B01001A_001E                            Estimate!!Total:
# ...             ...                                         ...
# 27075            UA                                   Geography
# 27076          ZCTA                                   Geography
# 27077           for                Census API FIPS 'for' clause
# 27078            in                 Census API FIPS 'in' clause
# 27079         ucgid  Uniform Census Geography Identifier clause
#
#                                   concept predicateType    group limit  \
# 0                                     NaN           NaN      N/A     0
# ...

# %%
testVars = ["B02001_001E", "B02001_002E", "B02001_003E", "B02001_004E", "B02001_005E", "B02001_006E", "B02001_007E", "B02001_008E", "B02001_009E", "B02001_010E", "B19013_001E", "B19013A_001E", "B19013B_001E", "B19013C_001E", "B19013D_001E", "B19013E_001E", "B19013F_001E", "B19013G_001E", "B19013H_001E", "B19013I_001E"]

# %%
az = acs.from_state('AZ',level='tract',variables= varList)
az.shape # of tracts
# Out:
# /Users/juanmozosnieto/opt/anaconda3/lib/python3.9/site-packages/cenpy/products.py:767: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   return self._from_name(state, variables, level, "States", **kwargs)
# /Users/juanmozosnieto/opt/anaconda3/lib/python3.9/site-packages/geopandas/geodataframe.py:1443: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# (1526, 675)

# %%
dict = {"B02001_001E": "Tot.Pop",
        "B02001_002E": "Tot.WhitePop",
 "B02001_003E": "Tot.BlackPop", 
 "B02001_004E": "Tot.AmericIndianPop",
 "B02001_005E": "Tot.AsianPop",
 "B02001_006E": "Tot.NativeHawaiianPacificPop",
 "B02001_007E": "Tot.OtherRaceAlonePop",
 "B02001_008E": "Tot.TwoOrMoreRace",
 "B02001_009E": "Tot.TwoOrMoreRace(Some other race)",
 'B03002_0012': "Tot.Hispanic/Latino",
 'B03002_002': "Tot.NotHispanic/Latino",
 'B25006_001E': "Tot.Householder",
 'B25006_002E': "Tot.WhiteHouseholder",
 'B25006_003E': "Tot.BlackHouseholder",
 'B25006_004E': "Tot.AmericanIndHouseholder",
 'B25006_005E': "Tot.AsianHouseholder",
 'B25006_006E': "Tot.HawaiiPacificHouseholder",
 'B25006_007E': "Tot.OtherRaceHouseholder",
 'B25006_008E': "Tot.TwoOrMoreRaceHouseholder",
 'B25006_009E': "Tot.TwoOrMoreRaceHouseholder(Some other race)",
 'B19001_001E': "Tot.HousehIncome",
 'B19001A_001E': "Tot.WhiteHousehIncome",
 'B19001B_001E': "Tot.BlackHousehIncome",
 'B19001C_001E': "Tot.AmericanIndianHousehIncome",
 'B19001D_001E': "Tot.AsianHousehIncome",
 'B19001E_001E': "Tot.HawaiiPacificHousehIncome",
 'B19001F_001E': "Tot.OtherRaceHousehIncome",
 'B19001G_001E': "Tot.TwoMoreRacesHousehIncome",
 'B19001H_001E': "Tot.WhiteNotHispanicLatinoHousehIncome",
 'B19001I_001E': "Tot.HispanicLatinoHousehIncome",
 'B19013_001E': "Med.HousehIncome",
 'B19013A_001E': "Med.WhiteHousehIncome",
 'B19013B_001E': "Med.BlackHousehIncome",
 'B19013C_001E': "Med.AmericanIndianHousehIncome",
 'B19013D_001E': "Med.AsianHousehIncome",
 'B19013E_001E': "Med.HawaiiPacificHousehIncome",
 'B19013F_001E': "Med.OtherRaceHousehIncome",
 'B19013G_001E': "Med.TwoOrMoreRacesHousehIncome",
 'B19013H_001E': "Med.WhiteNotHispanicLatinoHousehIncome",
 'B19013I_001E': "Med.HispanicLatinoHousehIncome",
 'C17002_001E': "RatioIncomeToPovertyLevel",
 'B01002G_002E': "MaleTwoOrMoreRacesMed.Age",
 'B01002G_003E': "FemaleTwoOrMoreRacesMed.Age",
 'B01002H_001E': "WhiteNotHispanicLatinoMed.Age",
 'B01002H_002E': "MaleWhiteNotHispanicLatinoMed.Age",
 'B01002H_003E': "FemaleWhiteNotHispanicLatinoMed.Age",
 'B01002I_001E': "HispanicLatinoMed.Age",
 'B01002I_002E': "MaleHispanicLatinoMed.Age",
 'B01002I_003E': "FemaleHispanicLatinoMed.Age",
 'B01003_001E': "TOTALPOP"}

# %%
az.rename(columns = {"B02001_001E": "TotalPop", 
                     "B02001_002E": "TotalWhite",
                     "B02001_003E": "TotalBlack", 
                     "B02001_004E": "TotalAmericIndian",
                     "B02001_005E": "Asian"}, inplace=True)

# %%
az.head(10)
# Out:
#          GEOID                                           geometry  TotalPop  \
# 0  04027011000  POLYGON ((-12776137.850 3846534.780, -12776135...    1848.0
# 1  04027000907  POLYGON ((-12764723.370 3853408.390, -12764711...    6936.0
# 2  04015952003  POLYGON ((-12757980.860 4167616.330, -12757980...    5098.0
# 3  04027011104  POLYGON ((-12745593.450 3851626.960, -12745593...    4177.0
# 4  04027011110  POLYGON ((-12739866.280 3851192.820, -12739863...    3142.0
# 5  04027011111  POLYGON ((-12747449.480 3846793.870, -12747450...    3504.0
# 6  04015952700  POLYGON ((-12728283.380 4096790.530, -12728242...    6120.0
# 7  04012020602  POLYGON ((-12771821.210 3935729.940, -12771674...    1527.0
# 8  04015952800  POLYGON ((-12725235.900 4095992.210, -12725235...    6421.0
# 9  04012940300  POLYGON ((-12750074.280 4019233.260, -12750070...    4937.0
#
#    TotalWhite  TotalBlack  TotalAmericIndian  Asian  B02001_006E  B02001_007E  \
# ...

# %%
varList
# Out:
# ['B02001_001E',
#  'B02001_002E',
#  'B02001_003E',
#  'B02001_004E',
#  'B02001_005E',
#  'B02001_006E',
#  'B02001_007E',
#  'B02001_008E',
#  'B02001_009E',
#  'B02001_010E',
#  'B03002_001',
#  'B03002_002',
#  'B03002_012',
#  'B25006_001E',
#  'B25006_002E',
#  'B25006_003E',
#  'B25006_004E',
#  'B25006_005E',
#  'B25006_006E',
#  'B25006_007E',
#  'B25006_008E',
#  'B25006_009E',
#  'B25006_010E',
#  'B19001_001E',
#  'B19001_002E',
#  'B19001_003E',
#  'B19001_004E',
#  'B19001_005E',
#  'B19001_006E',
#  'B19001_007E',
#  'B19001_008E',
#  'B19001_009E',
#  'B19001_010E',
#  'B19001_011E',
#  'B19001_012E',
#  'B19001_013E',
#  'B19001_014E',
#  'B19001_015E',
#  'B19001_016E',
#  'B19001_017E',
#  'B19001A_001E',
#  'B19001A_002E',
#  'B19001A_003E',
#  'B19001A_004E',
#  'B19001A_005E',
#  'B19001A_006E',
#  'B19001A_007E',
#  'B19001A_008E',
#  'B19001A_009E',
#  'B19001A_010E',
#  'B19001A_011E',
#  'B19001A_012E',
#  'B19001A_013E',
#  'B19001A_014E',
# ...
