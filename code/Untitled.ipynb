# %%
import os
import csv
import pandas as pd
import numpy as np

# %%
hmda = pd.read_csv('../input_data_clean/bank_tract_clean_WITH_CENSUS.csv')

# %%
hmda.describe(include='all')
# Out:
#           Unnamed: 0                                           NAME  \
# count   13837.000000                                          13837
# unique           NaN                                           9340
# top              NaN  Census Tract 4001, Alameda County, California
# freq             NaN                                              2
# mean     6918.000000                                            NaN
# std      3994.542172                                            NaN
# min         0.000000                                            NaN
# 25%      3459.000000                                            NaN
# 50%      6918.000000                                            NaN
# 75%     10377.000000                                            NaN
# max     13836.000000                                            NaN
#
#              Tot.Pop  Tot.WhitePop  Tot.BlackPop   Tot.AmericIndianPop  \
# count   13837.000000  13837.000000   13837.000000         13837.000000
# unique           NaN           NaN            NaN                  NaN
# top              NaN           NaN            NaN                  NaN
# freq             NaN           NaN            NaN                  NaN
# mean     5002.782250   3127.567464     267.177062            45.677965
# std      2252.169347   1705.709508     420.666721           114.805245
# min         0.000000      0.000000       0.000000             0.000000
# 25%      3546.000000   1937.000000      38.000000             0.000000
# 50%      4697.000000   2887.000000     121.000000            16.000000
# 75%      6022.000000   4000.000000     317.000000            50.000000
# max     31118.000000  17778.000000    5801.000000          4259.000000
#
#         Tot.AsianPop  Tot.NativeHawaiianPacificPop  Tot.OtherRaceAlonePop  \
# count   13837.000000                  13837.000000           13837.000000
# unique           NaN                           NaN                    NaN
# top              NaN                           NaN                    NaN
# freq             NaN                           NaN                    NaN
# mean      698.570283                     18.599624             602.436077
# std       991.409357                     54.647210             747.692894
# min         0.000000                      0.000000               0.000000
# 25%       113.000000                      0.000000             109.000000
# 50%       345.000000                      0.000000             316.000000
# 75%       846.000000                     12.000000             813.000000
# max     13013.000000                    838.000000            7961.000000
#
#         Tot.TwoOrMoreRace  ...      mean_LTV  mean_approved_rate_spread  \
# count        13837.000000  ...  13833.000000               13249.000000
# unique                NaN  ...           NaN                        NaN
# top                   NaN  ...           NaN                        NaN
# freq                  NaN  ...           NaN                        NaN
# mean           242.753776  ...     63.655351                   0.356823
# std            202.612442  ...     19.763747                   0.377184
# min              0.000000  ...      2.884700                  -1.206333
# 25%            107.000000  ...     55.788607                   0.160000
# 50%            197.000000  ...     64.124411                   0.295000
# 75%            323.000000  ...     72.347100                   0.474735
# max           2718.000000  ...   1815.708527                   4.011731
#
#         mean_approved_interest_rate  num_approved_loans  num_applications  \
# count                  13837.000000        13837.000000      13837.000000
# unique                          NaN                 NaN               NaN
# top                             NaN                 NaN               NaN
# freq                            NaN                 NaN               NaN
# mean                       3.144830           37.488328         44.738094
# std                        0.444966           46.537278         54.436187
# min                        1.583000            1.000000          1.000000
# 25%                        2.928137            3.000000          4.000000
# 50%                        3.031250           25.000000         31.000000
# 75%                        3.187483           55.000000         66.000000
# max                        7.675000          836.000000        964.000000
#
#         sum_all_loan_amount  median_all_income  acceptance_rate   denial_rate  \
# count          1.383700e+04       13435.000000     13837.000000  13837.000000
# unique                  NaN                NaN              NaN           NaN
# top                     NaN                NaN              NaN           NaN
# freq                    NaN                NaN              NaN           NaN
# mean           2.057061e+07         153.556085         0.819544      0.180456
# std            3.199159e+07         327.767463         0.156248      0.156248
# min            1.500000e+04           0.000000         0.142857      0.000000
# 25%            1.690000e+06          84.000000         0.756098      0.077922
# 50%            1.104000e+07         114.000000         0.845528      0.154472
# 75%            2.679500e+07         170.000000         0.922078      0.243902
# max            8.277450e+08       33827.000000         1.000000      0.857143
#
#         avg_approved_loan_size
# count             1.383700e+04
# unique                     NaN
# top                        NaN
# freq                       NaN
# mean              4.825314e+05
# std               9.985875e+05
# min               1.500000e+04
# 25%               2.550000e+05
# 50%               3.794681e+05
# 75%               5.339017e+05
# max               5.524500e+07
#
# [11 rows x 466 columns]

# %%
column_names = hmda.columns.tolist()
column_names_series = pd.Series(column_names)
print(column_names_series.to_string(index=False))
# Out:
#                                    Unnamed: 0
#                                          NAME
#                                       Tot.Pop
#                                  Tot.WhitePop
#                                 Tot.BlackPop
#                           Tot.AmericIndianPop
#                                  Tot.AsianPop
#                  Tot.NativeHawaiianPacificPop
#                         Tot.OtherRaceAlonePop
#                             Tot.TwoOrMoreRace
#            Tot.TwoOrMoreRace(Some other race)
#                           Tot.Hispanic/Latino
#                        Tot.NotHispanic/Latino
#                               Tot.Householder
#                          Tot.WhiteHouseholder
#                          Tot.BlackHouseholder
#                    Tot.AmericanIndHouseholder
#                          Tot.AsianHouseholder
#                  Tot.HawaiiPacificHouseholder
#                      Tot.OtherRaceHouseholder
#                  Tot.TwoOrMoreRaceHouseholder
# Tot.TwoOrMoreRaceHouseholder(Some other race)
#                              Tot.HousehIncome
#                         Tot.WhiteHousehIncome
#                         Tot.BlackHousehIncome
#                Tot.AmericanIndianHousehIncome
#                         Tot.AsianHousehIncome
#                 Tot.HawaiiPacificHousehIncome
#                     Tot.OtherRaceHousehIncome
#                  Tot.TwoMoreRacesHousehIncome
#        Tot.WhiteNotHispanicLatinoHousehIncome
#                Tot.HispanicLatinoHousehIncome
#                              Med.HousehIncome
#                         Med.WhiteHousehIncome
#                         Med.BlackHousehIncome
#                Med.AmericanIndianHousehIncome
#                         Med.AsianHousehIncome
#                 Med.HawaiiPacificHousehIncome
#                     Med.OtherRaceHousehIncome
#                Med.TwoOrMoreRacesHousehIncome
#        Med.WhiteNotHispanicLatinoHousehIncome
#                Med.HispanicLatinoHousehIncome
#                     RatioIncomeToPovertyLevel
#                                 Tot.Mortgaged
#                              Tot.NotMortgaged
#                     Med.HousehIncomeMortgaged
#                  Med.HousehIncomeNotMortgaged
#                Med.GrossRentAs%OfHousehIncome
#                    GrossRentAs%OfHousehIncome
#                                    Agg.Income
#                                        GEO_ID
#                                         state
#                                        county
#                                         tract
#                               WhiteAgg.Income
#                               BlackAgg.Income
#                      AmericanIndianAgg.Income
#                               AsianAgg.Income
#                       HawaiiPacificAgg.Income
#                          OtherRacesAgg.Income
#                      TowOrMoreRacesAgg.Income
#            WhiteNotHispanicOrLatinoAgg.Income
#                      HispanicLatinoAgg.Income
#                                 PerCap.Income
#                            WhitePerCap.Income
#                            BlackPerCap.Income
#                   AmericanIndianPerCap.Income
#                            AsianPerCap.Income
#                    HawaiiPacificPerCap.Income
#                       OtherRacesPerCap.Income
#                   TwoOrMoreracesPerCap.Income
#           WhiteNotHispanicLatinoPerCap.Income
#                   HispanicLatinoPerCap.Income
#                                 Med.FamIncome
#                            WhiteMed.FamIncome
#                            BlackMed.FamIncome
#                   AmericanIndianMed.FamIncome
#                            AsianMed.FamIncome
#                    HawaiiPacificMed.FamIncome
#                       OtherRacesMed.FamIncome
#                   TwoOrMoreRacesMed.FamIncome
#           WhiteNotHispanicLatinoMed.FamIncome
#                   HispanicLatinoMed.FamIncome
#                                    Fam.Income
#                               WhiteFam.Income
#                               BlackFam.Income
#                      AmericanIndianFam.Income
#                               AsianFam.Income
#                       HawaiiPacificFam.Income
#                          OtherRacesFam.Income
#                      TwoOrMoreracesFam.Income
#              WhiteNotHispanicLatinoFam.Income
#                      HispanicLatinoFam.Income
#                        Agg.SalaryIncomeHouseh
#                               TotalPopulation
#                                       MalePop
#                                 MalePopUnder5
#                                    MalePop5-9
#                                  MalePop10-14
#                                  MalePop15-17
#                                  MalePop18-19
#                                     MalePop20
#                                     MalePop21
#                                  MalePop22-24
#                                  MalePop25-29
#                                  MalePop30-34
#                                  MalePop35-39
#                                  MalePop40-44
#                                  MalePop45-49
#                                  MalePop50-54
#                                  MalePop55-59
#                                  MalePop60-61
#                                  MalePop62-64
#                                  MalePop65-66
#                                  MalePop67-69
#                                  MalePop70-74
#                                  MalePop75-79
#                                  MalePop80-84
#                                 MalePop85More
#                                     FemalePop
#                               FemalePopUnder5
#                                  FemalePop5-9
#                                FemalePop10-14
#                                FemalePop15-17
#                                FemalePop18-19
#                                   FemalePop20
#                                   FemalePop21
#                                FemalePop22-24
#                                FemalePop25-29
#                                FemalePop30-34
#                                FemalePop35-39
#                                FemalePop40-44
#                                FemalePop45-49
#                                FemalePop50-54
#                                FemalePop55-59
#                                FemalePop60-61
#                                FemalePop62-64
#                                FemalePop65-66
#                                FemalePop67-69
#                                FemalePop70-74
#                                FemalePop75-79
#                                FemalePop80-84
#                               FemalePop85More
#                                      WhitePop
#                                  MaleWhitePop
#                            MaleWhitePopUnder5
#                               MaleWhitePop5-9
#                             MaleWhitePop10-14
#                             MaleWhitePop15-17
#                             MaleWhitePop18-19
#                             MaleWhitePop20-24
#                             MaleWhitePop25-29
#                             MaleWhitePop30-34
#                             MaleWhitePop35-44
#                             MaleWhitePop45-54
#                             MaleWhitePop55-64
#                             MaleWhitePop65-74
#                             MaleWhitePop75-84
#                            MaleWhitePop85More
#                                FemaleWhitePop
#                          FemaleWhitePopUnder5
#                             FemaleWhitePop5-9
#                           FemaleWhitePop10-14
#                           FemaleWhitePop15-17
#                           FemaleWhitePop18-19
#                           FemaleWhitePop20-24
#                           FemaleWhitePop25-29
#                           FemaleWhitePop30-34
#                           FemaleWhitePop35-44
#                           FemaleWhitePop45-54
#                           FemaleWhitePop55-64
#                           FemaleWhitePop65-74
#                           FemaleWhitePop75-84
#                          FemaleWhitePop85More
#                                      BlackPop
#                                  MaleBlackPop
#                            MaleBlackPopUnder5
#                               MaleBlackPop5-9
#                             MaleBlackPop10-14
#                             MaleBlackPop15-17
#                             MaleBlackPop18-19
#                             MaleBlackPop20-24
#                             MaleBlackPop25-29
#                             MaleBlackPop30-34
#                             MaleBlackPop35-44
#                             MaleBlackPop45-54
#                             MaleBlackPop55-64
#                             MaleBlackPop65-74
#                             MaleBlackPop75-84
#                            MaleBlackPop85More
#                                FemaleBlackPop
#                          FemaleBlackPopUnder5
#                             FemaleBlackPop5-9
#                           FemaleBlackPop10-14
#                           FemaleBlackPop15-17
#                           FemaleBlackPop18-19
#                           FemaleBlackPop20-24
#                           FemaleBlackPop25-29
#                           FemaleBlackPop30-34
#                           FemaleBlackPop35-44
#                           FemaleBlackPop45-54
#                           FemaleBlackPop55-64
#                           FemaleBlackPop65-74
#                           FemaleBlackPop75-84
#                          FemaleBlackPop85More
#                            AmericanInadianPop
#                         MaleAmericanIndianPop
#                   MaleAmericanIndianPopUnder5
#                      MaleAmericanIndianPop5-9
#                    MaleAmericanIndianPop10-14
#                    MaleAmericanIndianPop15-17
#                    MaleAmericanIndianPop18-19
#                    MaleAmericanIndianPop20-24
#                    MaleAmericanIndianPop25-29
#                    MaleAmericanIndianPop30-34
#                    MaleAmericanIndianPop35-44
#                    MaleAmericanIndianPop45-54
#                    MaleAmericanIndianPop55-64
#                    MaleAmericanIndianPop65-74
#                    MaleAmericanIndianPop75-84
#                   MaleAmericanIndianPop85More
#                       FemaleAmericanIndianPop
#                 FemaleAmericanIndianPopUnder5
#                    FemaleAmericanIndianPop5-9
#                  FemaleAmericanIndianPop10-14
#                  FemaleAmericanIndianPop15-17
#                  FemaleAmericanIndianPop18-19
#                  FemaleAmericanIndianPop20-24
#                  FemaleAmericanIndianPop25-29
#                  FemaleAmericanIndianPop30-34
#                  FemaleAmericanIndianPop35-44
#                  FemaleAmericanIndianPop45-54
#                  FemaleAmericanIndianPop55-64
#                  FemaleAmericanIndianPop65-74
#                  FemaleAmericanIndianPop75-84
#                 FemaleAmericanIndianPop85More
#                                      AsianPop
#                                  MaleAsianPop
#                            MaleAsianPopUnder5
#                               MaleAsianPop5-9
#                             MaleAsianPop10-14
#                             MaleAsianPop15-17
#                             MaleAsianPop18-19
#                             MaleAsianPop20-24
#                             MaleAsianPop25-29
#                             MaleAsianPop30-34
#                             MaleAsianPop35-44
#                             MaleAsianPop45-54
#                             MaleAsianPop55-64
#                             MaleAsianPop65-74
#                             MaleAsianPop75-84
#                            MaleAsianPop85More
#                                FemaleAsianPop
#                          FemaleAsianPopUnder5
#                             FemaleAsianPop5-9
#                           FemaleAsianPop10-14
#                           FemaleAsianPop15-17
#                           FemaleAsianPop18-19
#                           FemaleAsianPop20-24
#                           FemaleAsianPop25-29
#                           FemaleAsianPop30-34
#                           FemaleAsianPop35-44
#                           FemaleAsianPop45-54
#                           FemaleAsianPop55-64
#                           FemaleAsianPop65-74
#                           FemaleAsianPop75-84
#                          FemaleAsianPop85More
#                              HawaiiPacificPop
#                          MaleHawaiiPacificPop
#                    MaleHawaiiPacificPopUnder5
#                       MaleHawaiiPacificPop5-9
#                     MaleHawaiiPacificPop10-14
#                     MaleHawaiiPacificPop15-17
#                     MaleHawaiiPacificPop18-19
#                     MaleHawaiiPacificPop20-24
#                     MaleHawaiiPacificPop25-29
#                     MaleHawaiiPacificPop30-34
#                     MaleHawaiiPacificPop35-44
#                     MaleHawaiiPacificPop45-54
#                     MaleHawaiiPacificPop55-64
#                     MaleHawaiiPacificPop65-74
#                     MaleHawaiiPacificPop75-84
#                    MaleHawaiiPacificPop85More
#                        FemaleHawaiiPacificPop
#                  FemaleHawaiiPacificPopUnder5
#                     FemaleHawaiiPacificPop5-9
#                   FemaleHawaiiPacificPop10-14
#                   FemaleHawaiiPacificPop15-17
#                   FemaleHawaiiPacificPop18-19
#                   FemaleHawaiiPacificPop20-24
#                   FemaleHawaiiPacificPop25-29
#                   FemaleHawaiiPacificPop30-34
#                   FemaleHawaiiPacificPop35-44
#                   FemaleHawaiiPacificPop45-54
#                   FemaleHawaiiPacificPop55-64
#                   FemaleHawaiiPacificPop65-74
#                   FemaleHawaiiPacificPop75-84
#                  FemaleHawaiiPacificPop85More
#                                  OtherRacePop
#                              MaleOtherRacePop
#                        MaleOtherRacePopUnder5
#                           MaleOtherRacePop5-9
#                         MaleOtherRacePop10-14
#                         MaleOtherRacePop15-17
#                         MaleOtherRacePop18-19
#                         MaleOtherRacePop20-24
#                         MaleOtherRacePop25-29
#                         MaleOtherRacePop30-34
#                         MaleOtherRacePop35-44
#                         MaleOtherRacePop45-54
#                         MaleOtherRacePop55-64
#                         MaleOtherRacePop65-74
#                         MaleOtherRacePop75-84
#                        MaleOtherRacePop85More
#                            FemaleOtherRacePop
#                      FemaleOtherRacePopUnder5
#                         FemaleOtherRacePop5-9
#                       FemaleOtherRacePop10-14
#                       FemaleOtherRacePop15-17
#                       FemaleOtherRacePop18-19
#                       FemaleOtherRacePop20-24
#                       FemaleOtherRacePop25-29
#                       FemaleOtherRacePop30-34
#                       FemaleOtherRacePop35-44
#                       FemaleOtherRacePop45-54
#                       FemaleOtherRacePop55-64
#                       FemaleOtherRacePop65-74
#                       FemaleOtherRacePop75-84
#                      FemaleOtherRacePop85More
#                             TwoOrMoreRacesPop
#                         MaleTwoOrMoreRacesPop
#                   MaleTwoOrMoreRacesPopUnder5
#                      MaleTwoOrMoreRacesPop5-9
#                    MaleTwoOrMoreRacesPop10-14
#                    MaleTwoOrMoreRacesPop15-17
#                    MaleTwoOrMoreRacesPop18-19
#                    MaleTwoOrMoreRacesPop20-24
#                    MaleTwoOrMoreRacesPop25-29
#                    MaleTwoOrMoreRacesPop30-34
#                    MaleTwoOrMoreRacesPop35-44
#                    MaleTwoOrMoreRacesPop45-54
#                    MaleTwoOrMoreRacesPop55-64
#                    MaleTwoOrMoreRacesPop65-74
#                    MaleTwoOrMoreRacesPop75-84
#                   MaleTwoOrMoreRacesPop85More
#                       FemaleTwoOrMoreRacesPop
#                 FemaleTwoOrMoreRacesPopUnder5
#                    FemaleTwoOrMoreRacesPop5-9
#                  FemaleTwoOrMoreRacesPop10-14
#                  FemaleTwoOrMoreRacesPop15-17
#                  FemaleTwoOrMoreRacesPop18-19
#                  FemaleTwoOrMoreRacesPop20-24
#                  FemaleTwoOrMoreRacesPop25-29
#                  FemaleTwoOrMoreRacesPop30-34
#                  FemaleTwoOrMoreRacesPop35-44
#                  FemaleTwoOrMoreRacesPop45-54
#                  FemaleTwoOrMoreRacesPop55-64
#                  FemaleTwoOrMoreRacesPop65-74
#                  FemaleTwoOrMoreRacesPop75-84
#                 FemaleTwoOrMoreRacesPop85More
#                     WhiteNotHispanicLatinoPop
#                 MaleWhiteNotHispanicLatinoPop
#           MaleWhiteNotHispanicLatinoPopUnder5
#              MaleWhiteNotHispanicLatinoPop5-9
#            MaleWhiteNotHispanicLatinoPop10-14
#            MaleWhiteNotHispanicLatinoPop15-17
#            MaleWhiteNotHispanicLatinoPop18-19
#            MaleWhiteNotHispanicLatinoPop20-24
#            MaleWhiteNotHispanicLatinoPop25-29
#            MaleWhiteNotHispanicLatinoPop30-34
#            MaleWhiteNotHispanicLatinoPop35-44
#            MaleWhiteNotHispanicLatinoPop45-54
#            MaleWhiteNotHispanicLatinoPop55-64
#            MaleWhiteNotHispanicLatinoPop65-74
#            MaleWhiteNotHispanicLatinoPop75-84
#           MaleWhiteNotHispanicLatinoPop85More
#               FemaleWhiteNotHispanicLatinoPop
#         FemaleWhiteNotHispanicLatinoPopUnder5
#            FemaleWhiteNotHispanicLatinoPop5-9
#          FemaleWhiteNotHispanicLatinoPop10-14
#          FemaleWhiteNotHispanicLatinoPop15-17
#          FemaleWhiteNotHispanicLatinoPop18-19
#          FemaleWhiteNotHispanicLatinoPop20-24
#          FemaleWhiteNotHispanicLatinoPop25-29
#          FemaleWhiteNotHispanicLatinoPop30-34
#          FemaleWhiteNotHispanicLatinoPop35-44
#          FemaleWhiteNotHispanicLatinoPop45-54
#          FemaleWhiteNotHispanicLatinoPop55-64
#          FemaleWhiteNotHispanicLatinoPop65-74
#          FemaleWhiteNotHispanicLatinoPop75-84
#         FemaleWhiteNotHispanicLatinoPop85More
#                             HispanicLatinoPop
#                         MaleHispanicLatinoPop
#                   MaleHispanicLatinoPopUnder5
#                      MaleHispanicLatinoPop5-9
#                    MaleHispanicLatinoPop10-14
#                    MaleHispanicLatinoPop15-17
#                    MaleHispanicLatinoPop18-19
#                    MaleHispanicLatinoPop20-24
#                    MaleHispanicLatinoPop25-29
#                    MaleHispanicLatinoPop30-34
#                    MaleHispanicLatinoPop35-44
#                    MaleHispanicLatinoPop45-54
#                    MaleHispanicLatinoPop55-64
#                    MaleHispanicLatinoPop65-74
#                    MaleHispanicLatinoPop75-84
#                   MaleHispanicLatinoPop85More
#                       FemaleHispanicLatinoPop
#                 FemaleHispanicLatinoPopUnder5
#                    FemaleHispanicLatinoPop5-9
#                  FemaleHispanicLatinoPop10-14
#                  FemaleHispanicLatinoPop15-17
#                  FemaleHispanicLatinoPop18-19
#                  FemaleHispanicLatinoPop20-24
#                  FemaleHispanicLatinoPop25-29
#                  FemaleHispanicLatinoPop30-34
#                  FemaleHispanicLatinoPop35-44
#                  FemaleHispanicLatinoPop45-54
#                  FemaleHispanicLatinoPop55-64
#                  FemaleHispanicLatinoPop65-74
#                  FemaleHispanicLatinoPop75-84
#                 FemaleHispanicLatinoPop85More
#                                       Med.Age
#                                   MaleMed.Age
#                                 FemaleMed.Age
#                                  WhiteMed.Age
#                              MaleWhiteMed.Age
#                            FemaleWhiteMed.Age
#                                  BlackMed.Age
#                              MaleBlackMed.Age
#                            FemaleBlackMed.Age
#                         AmericanIndianMed.Age
#                     MaleAmericanIndianMed.Age
#                   FemaleAmericanIndianMed.Age
#                                  AsianMed.Age
#                              MaleAsianMed.Age
#                            FemaleAsianMed.Age
#                          HawaiiPacificMed.Age
#                      MaleHawaiiPacificMed.Age
#                    FemaleHawaiiPacificMed.Age
#                              OtherRaceMed.Age
#                          MaleOtherRaceMed.Age
#                        FemaleOtherRaceMed.Age
#                         TwoOrMoreRacesMed.Age
#                     MaleTwoOrMoreRacesMed.Age
#                   FemaleTwoOrMoreRacesMed.Age
#                 WhiteNotHispanicLatinoMed.Age
#             MaleWhiteNotHispanicLatinoMed.Age
#           FemaleWhiteNotHispanicLatinoMed.Age
#                         HispanicLatinoMed.Age
#                     MaleHispanicLatinoMed.Age
#                   FemaleHispanicLatinoMed.Age
#                                      TOTALPOP
#                                  census_tract
#                                    which_bank
#                            sum_approved_loans
#                                      mean_LTV
#                     mean_approved_rate_spread
#                   mean_approved_interest_rate
#                            num_approved_loans
#                              num_applications
#                           sum_all_loan_amount
#                             median_all_income
#                               acceptance_rate
#                                   denial_rate
#                        avg_approved_loan_size

# %%
numvars = len(column_names_series)
print(numvars)
# Out:
# 466

# %%
#cols_of_interest= [‘Tot.HousehIncome’ , ‘Med.HousehIncome’, ‘RatioIncomeToPovertyLevel, ‘Agg.Income’, 
 #                  ‘PerCap.Income’, ‘Med.FamIncome’, ‘Fam.Income’, ‘WhiteFam.Income’ , ‘BlackFam.Income’, 
  #                 ‘AmericanIndianFam.Income’, ‘AsianFam.Income’, ‘HawaiiPacificFam.Income’, ‘OtherRacesFam.Income’, 
   #                ‘TwoOrMoreracesFam.Income’, ‘TotalPopulation’, ‘Med.Age’, ‘TOTALPOP’, ‘sum_approved_loans’, 
    #               ‘mean_LTV’, ‘mean_approved_rate_spread’, ‘mean_approved_interest_rate’, ‘num_approved_loans’, 
     #              ‘num_applications’, ‘sum_all_loan_amount’, ‘median_all_income’, ‘acceptance_rate’, 
      #             ‘denial_rate’, ‘avg_approved_loan_size’]
cols_of_interest= ['sum_approved_loans', 'mean_LTV', 'mean_approved_rate_spread', 
                   'mean_approved_interest_rate', 'num_approved_loans', 'num_applications', 
                   'sum_all_loan_amount', 'median_all_income', 'acceptance_rate', 'denial_rate', 
                   'avg_approved_loan_size']

subset_df = hmda[cols_of_interest]
stats = subset_df.describe()
print(stats)
# Out:
#        sum_approved_loans      mean_LTV  mean_approved_rate_spread  \
# count        1.383700e+04  13833.000000               13249.000000
# mean         1.781060e+07     63.655351                   0.356823
# std          2.830304e+07     19.763747                   0.377184
# min          1.500000e+04      2.884700                  -1.206333
# 25%          1.225000e+06     55.788607                   0.160000
# 50%          9.125000e+06     64.124411                   0.295000
# 75%          2.310000e+07     72.347100                   0.474735
# max          6.387400e+08   1815.708527                   4.011731
#
#        mean_approved_interest_rate  num_approved_loans  num_applications  \
# count                 13837.000000        13837.000000      13837.000000
# mean                      3.144830           37.488328         44.738094
# std                       0.444966           46.537278         54.436187
# min                       1.583000            1.000000          1.000000
# 25%                       2.928137            3.000000          4.000000
# 50%                       3.031250           25.000000         31.000000
# 75%                       3.187483           55.000000         66.000000
# max                       7.675000          836.000000        964.000000
#
#        sum_all_loan_amount  median_all_income  acceptance_rate   denial_rate  \
# count         1.383700e+04       13435.000000     13837.000000  13837.000000
# mean          2.057061e+07         153.556085         0.819544      0.180456
# std           3.199159e+07         327.767463         0.156248      0.156248
# min           1.500000e+04           0.000000         0.142857      0.000000
# 25%           1.690000e+06          84.000000         0.756098      0.077922
# 50%           1.104000e+07         114.000000         0.845528      0.154472
# 75%           2.679500e+07         170.000000         0.922078      0.243902
# max           8.277450e+08       33827.000000         1.000000      0.857143
#
#        avg_approved_loan_size
# count            1.383700e+04
# mean             4.825314e+05
# std              9.985875e+05
# min              1.500000e+04
# 25%              2.550000e+05
# 50%              3.794681e+05
# 75%              5.339017e+05
# max              5.524500e+07

# %%
dstats = 'statistics.csv'
stats.to_csv(dstats, index=True)

# %%
df = pd.read_csv('../input_data_clean/state_AZ-CA_clean.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/9_/bh1x6dbx33z0dhsp9gs3_fpm0000gn/T/ipykernel_22880/3116927081.py in <module>
# ----> 1 df = pd.read_csv('../input_data_clean/state_AZ-CA_clean.csv')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../input_data_clean/state_AZ-CA_clean.csv'

# %%
df.describe(include='all')
