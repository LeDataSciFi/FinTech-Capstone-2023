# %%
import os
import csv
import pandas as pd
import numpy as np

# %% [markdown]
# # Analysis on HMDA file only

# %%
data = pd.read_csv('../input_data_clean/bank_tract_clean_WITH_CENSUS.csv')

# %%
hmda = pd.read_csv('../input_data_clean/state_AZ-CA_clean.csv')

# %% [markdown]
# ## Descriptive Stats

# %%
important_vars = ["sum_approved_loans", "mean_LTV", "mean_approved_rate_spread", "mean_approved_interest_rate", "num_approved_loans", "num_applications", "sum_all_loan_amount", "median_all_income", "acceptance_rate", "denial_rate", "avg_approved_loan_size"]

# %% [markdown]
# ### Whole Dataset Descriptive Stats

# %%
stats = data[important_vars].describe()
stats1 = stats.applymap("{:.4f}".format)
stats1
# Out:
#       sum_approved_loans    mean_LTV mean_approved_rate_spread  \
# count         13837.0000  13833.0000                13249.0000
# mean       17810599.8410     63.6554                    0.3568
# std        28303040.3389     19.7637                    0.3772
# min           15000.0000      2.8847                   -1.2063
# 25%         1225000.0000     55.7886                    0.1600
# 50%         9125000.0000     64.1244                    0.2950
# 75%        23100000.0000     72.3471                    0.4747
# max       638740000.0000   1815.7085                    4.0117
#
#       mean_approved_interest_rate num_approved_loans num_applications  \
# count                  13837.0000         13837.0000       13837.0000
# mean                       3.1448            37.4883          44.7381
# std                        0.4450            46.5373          54.4362
# min                        1.5830             1.0000           1.0000
# 25%                        2.9281             3.0000           4.0000
# 50%                        3.0312            25.0000          31.0000
# 75%                        3.1875            55.0000          66.0000
# max                        7.6750           836.0000         964.0000
#
#       sum_all_loan_amount median_all_income acceptance_rate denial_rate  \
# count          13837.0000        13435.0000      13837.0000  13837.0000
# mean        20570612.4883          153.5561          0.8195      0.1805
# std         31991587.3276          327.7675          0.1562      0.1562
# min            15000.0000            0.0000          0.1429      0.0000
# 25%          1690000.0000           84.0000          0.7561      0.0779
# 50%         11040000.0000          114.0000          0.8455      0.1545
# 75%         26795000.0000          170.0000          0.9221      0.2439
# max        827745000.0000        33827.0000          1.0000      0.8571
#
#       avg_approved_loan_size
# count             13837.0000
# mean             482531.4305
# std              998587.4655
# min               15000.0000
# 25%              255000.0000
# 50%              379468.0851
# 75%              533901.7341
# max            55245000.0000

# %% [markdown]
# ### BoW Descriptive Stats

# %%
BoW = data[data['which_bank'] == 'Bank of West']
BoW_stats = BoW[important_vars].describe()
BoW_stats1 = BoW_stats.applymap("{:.4f}".format)
BoW_stats1
# Out:
#       sum_approved_loans   mean_LTV mean_approved_rate_spread  \
# count          4500.0000  4498.0000                 3944.0000
# mean        1312934.4444    61.0495                    0.4715
# std         2561479.7027    17.3864                    0.5699
# min           15000.0000     2.8847                   -1.0950
# 25%          255000.0000    50.5067                    0.1600
# 50%          555000.0000    62.3757                    0.3155
# 75%         1355000.0000    74.5363                    0.6980
# max        54175000.0000   104.0000                    3.7100
#
#       mean_approved_interest_rate num_approved_loans num_applications  \
# count                   4500.0000          4500.0000        4500.0000
# mean                       3.4099             2.3949           3.3793
# std                        0.6667             2.1430           3.1830
# min                        1.5830             1.0000           1.0000
# 25%                        3.0000             1.0000           1.0000
# 50%                        3.2341             2.0000           2.0000
# 75%                        3.7231             3.0000           4.0000
# max                        7.6750            26.0000          41.0000
#
#       sum_all_loan_amount median_all_income acceptance_rate denial_rate  \
# count           4500.0000         4113.0000       4500.0000   4500.0000
# mean         1767376.6667          219.4200          0.7950      0.2050
# std          3263037.7061          575.7042          0.2397      0.2397
# min            15000.0000            0.0000          0.1429      0.0000
# 25%           330000.0000           99.0000          0.6000      0.0000
# 50%           760000.0000          155.0000          1.0000      0.0000
# 75%          1880000.0000          245.5000          1.0000      0.4000
# max         54930000.0000        33827.0000          1.0000      0.8571
#
#       avg_approved_loan_size
# count              4500.0000
# mean             480744.0037
# std             1349986.0823
# min               15000.0000
# 25%              195000.0000
# 50%              320000.0000
# 75%              565000.0000
# max            54175000.0000

# %% [markdown]
# ### Other Banks Descriptive Stats

# %%
All = data[data['which_bank'] == 'All Other Banks']
All_stats = All[important_vars].describe()
All_stats1 = All_stats.applymap("{:.4f}".format)
All_stats1
# Out:
#       sum_approved_loans   mean_LTV mean_approved_rate_spread  \
# count          9337.0000  9335.0000                 9305.0000
# mean       25761707.7220    64.9110                    0.3082
# std        31457918.9508    20.6966                    0.2388
# min           55000.0000    18.0100                   -1.2063
# 25%         8615000.0000    57.4065                    0.1593
# 50%        16830000.0000    64.6247                    0.2920
# 75%        31090000.0000    71.8632                    0.4323
# max       638740000.0000  1815.7085                    4.0117
#
#       mean_approved_interest_rate num_approved_loans num_applications  \
# count                   9337.0000          9337.0000        9337.0000
# mean                       3.0171            54.4017          64.6711
# std                        0.1705            48.2461          56.2573
# min                        1.7500             1.0000           1.0000
# 25%                        2.9155            24.0000          30.0000
# 50%                        3.0080            44.0000          53.0000
# 75%                        3.1055            69.0000          82.0000
# max                        4.7400           836.0000         964.0000
#
#       sum_all_loan_amount median_all_income acceptance_rate denial_rate  \
# count           9337.0000         9322.0000       9337.0000   9337.0000
# mean        29632898.1472          124.4960          0.8314      0.1686
# std         35483687.9307           76.5764          0.0898      0.0898
# min            55000.0000            0.0000          0.2000      0.0000
# 25%         10445000.0000           81.0000          0.7869      0.1111
# 50%         19935000.0000          105.0000          0.8421      0.1579
# 75%         36010000.0000          143.0000          0.8889      0.2131
# max        827745000.0000         1583.0000          1.0000      0.8000
#
#       avg_approved_loan_size
# count              9337.0000
# mean             483392.8872
# std              774324.2214
# min               55000.0000
# 25%              285714.2857
# 50%              394375.0000
# 75%              523333.3333
# max            55245000.0000

# %% [markdown]
# ## Denial rates by product and purpose (aggregate)

# %%
# the denial rate = denials/apps
# so restrict to applications

#apps = hmda.query('action_taken < 4').copy()

#apps['denial'] = apps['action_taken'] == 3

# Create the pivot table
pivot = hmda.pivot_table(index=['loant_type', 'loan_purpose'], columns = ['which_bank'], values='denial_rate', aggfunc='mean')

# add columns for differentials (easier to see)
pivot['diff_BMO'] = pivot['BMO Harris'] - pivot['All Other Banks']
pivot['diff_BOW'] = pivot['Bank of West'] - pivot['All Other Banks']
pivot.style.format('{:,.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_f507d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >which_bank</th>
#       <th id="T_f507d_level0_col0" class="col_heading level0 col0" >All Other Banks</th>
#       <th id="T_f507d_level0_col1" class="col_heading level0 col1" >BMO Harris</th>
#       <th id="T_f507d_level0_col2" class="col_heading level0 col2" >Bank of West</th>
#       <th id="T_f507d_level0_col3" class="col_heading level0 col3" >diff_BMO</th>
#       <th id="T_f507d_level0_col4" class="col_heading level0 col4" >diff_BOW</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >loan_type</th>
#       <th class="index_name level1" >loan_purpose</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f507d_level0_row0" class="row_heading level0 row0" rowspan="6">1</th>
#       <th id="T_f507d_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_f507d_row0_col0" class="data row0 col0" >0.10</td>
#       <td id="T_f507d_row0_col1" class="data row0 col1" >0.50</td>
#       <td id="T_f507d_row0_col2" class="data row0 col2" >0.12</td>
#       <td id="T_f507d_row0_col3" class="data row0 col3" >0.40</td>
#       <td id="T_f507d_row0_col4" class="data row0 col4" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_f507d_row1_col0" class="data row1 col0" >0.39</td>
#       <td id="T_f507d_row1_col1" class="data row1 col1" >0.62</td>
#       <td id="T_f507d_row1_col2" class="data row1 col2" >0.37</td>
#       <td id="T_f507d_row1_col3" class="data row1 col3" >0.24</td>
#       <td id="T_f507d_row1_col4" class="data row1 col4" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_f507d_row2_col0" class="data row2 col0" >0.38</td>
#       <td id="T_f507d_row2_col1" class="data row2 col1" >0.50</td>
#       <td id="T_f507d_row2_col2" class="data row2 col2" >0.30</td>
#       <td id="T_f507d_row2_col3" class="data row2 col3" >0.12</td>
#       <td id="T_f507d_row2_col4" class="data row2 col4" >-0.08</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level1_row3" class="row_heading level1 row3" >5</th>
#       <td id="T_f507d_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_f507d_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_f507d_row3_col2" class="data row3 col2" >nan</td>
#       <td id="T_f507d_row3_col3" class="data row3 col3" >nan</td>
#       <td id="T_f507d_row3_col4" class="data row3 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level1_row4" class="row_heading level1 row4" >31</th>
#       <td id="T_f507d_row4_col0" class="data row4 col0" >0.12</td>
#       <td id="T_f507d_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_f507d_row4_col2" class="data row4 col2" >0.26</td>
#       <td id="T_f507d_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_f507d_row4_col4" class="data row4 col4" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level1_row5" class="row_heading level1 row5" >32</th>
#       <td id="T_f507d_row5_col0" class="data row5 col0" >0.13</td>
#       <td id="T_f507d_row5_col1" class="data row5 col1" >0.75</td>
#       <td id="T_f507d_row5_col2" class="data row5 col2" >0.29</td>
#       <td id="T_f507d_row5_col3" class="data row5 col3" >0.62</td>
#       <td id="T_f507d_row5_col4" class="data row5 col4" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level0_row6" class="row_heading level0 row6" rowspan="5">2</th>
#       <th id="T_f507d_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_f507d_row6_col0" class="data row6 col0" >0.12</td>
#       <td id="T_f507d_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_f507d_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_f507d_row6_col3" class="data row6 col3" >nan</td>
#       <td id="T_f507d_row6_col4" class="data row6 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_f507d_row7_col0" class="data row7 col0" >0.43</td>
#       <td id="T_f507d_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_f507d_row7_col2" class="data row7 col2" >nan</td>
#       <td id="T_f507d_row7_col3" class="data row7 col3" >nan</td>
#       <td id="T_f507d_row7_col4" class="data row7 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level1_row8" class="row_heading level1 row8" >4</th>
#       <td id="T_f507d_row8_col0" class="data row8 col0" >0.22</td>
#       <td id="T_f507d_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_f507d_row8_col2" class="data row8 col2" >nan</td>
#       <td id="T_f507d_row8_col3" class="data row8 col3" >nan</td>
#       <td id="T_f507d_row8_col4" class="data row8 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level1_row9" class="row_heading level1 row9" >31</th>
#       <td id="T_f507d_row9_col0" class="data row9 col0" >0.17</td>
#       <td id="T_f507d_row9_col1" class="data row9 col1" >nan</td>
#       <td id="T_f507d_row9_col2" class="data row9 col2" >nan</td>
#       <td id="T_f507d_row9_col3" class="data row9 col3" >nan</td>
#       <td id="T_f507d_row9_col4" class="data row9 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level1_row10" class="row_heading level1 row10" >32</th>
#       <td id="T_f507d_row10_col0" class="data row10 col0" >0.30</td>
#       <td id="T_f507d_row10_col1" class="data row10 col1" >nan</td>
#       <td id="T_f507d_row10_col2" class="data row10 col2" >nan</td>
#       <td id="T_f507d_row10_col3" class="data row10 col3" >nan</td>
#       <td id="T_f507d_row10_col4" class="data row10 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level0_row11" class="row_heading level0 row11" rowspan="5">3</th>
#       <th id="T_f507d_level1_row11" class="row_heading level1 row11" >1</th>
#       <td id="T_f507d_row11_col0" class="data row11 col0" >0.06</td>
#       <td id="T_f507d_row11_col1" class="data row11 col1" >nan</td>
#       <td id="T_f507d_row11_col2" class="data row11 col2" >nan</td>
#       <td id="T_f507d_row11_col3" class="data row11 col3" >nan</td>
#       <td id="T_f507d_row11_col4" class="data row11 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_f507d_row12_col0" class="data row12 col0" >0.12</td>
#       <td id="T_f507d_row12_col1" class="data row12 col1" >nan</td>
#       <td id="T_f507d_row12_col2" class="data row12 col2" >nan</td>
#       <td id="T_f507d_row12_col3" class="data row12 col3" >nan</td>
#       <td id="T_f507d_row12_col4" class="data row12 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level1_row13" class="row_heading level1 row13" >4</th>
#       <td id="T_f507d_row13_col0" class="data row13 col0" >0.40</td>
#       <td id="T_f507d_row13_col1" class="data row13 col1" >nan</td>
#       <td id="T_f507d_row13_col2" class="data row13 col2" >nan</td>
#       <td id="T_f507d_row13_col3" class="data row13 col3" >nan</td>
#       <td id="T_f507d_row13_col4" class="data row13 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level1_row14" class="row_heading level1 row14" >31</th>
#       <td id="T_f507d_row14_col0" class="data row14 col0" >0.12</td>
#       <td id="T_f507d_row14_col1" class="data row14 col1" >nan</td>
#       <td id="T_f507d_row14_col2" class="data row14 col2" >nan</td>
#       <td id="T_f507d_row14_col3" class="data row14 col3" >nan</td>
#       <td id="T_f507d_row14_col4" class="data row14 col4" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f507d_level1_row15" class="row_heading level1 row15" >32</th>
#       <td id="T_f507d_row15_col0" class="data row15 col0" >0.25</td>
#       <td id="T_f507d_row15_col1" class="data row15 col1" >nan</td>
#       <td id="T_f507d_row15_col2" class="data row15 col2" >nan</td>
#       <td id="T_f507d_row15_col3" c

# %% [markdown]
# ## Avg requested loan size by product and purpose for all applications (aggregate)

# %%
hmda.pivot_table(index=['loant_type', 'loan_purpose'], 
                 columns = ['which_bank'], 
                 values='loan_amount', 
                 aggfunc='mean').style.format('{:,.0f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ec5f7">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >which_bank</th>
#       <th id="T_ec5f7_level0_col0" class="col_heading level0 col0" >All Other Banks</th>
#       <th id="T_ec5f7_level0_col1" class="col_heading level0 col1" >BMO Harris</th>
#       <th id="T_ec5f7_level0_col2" class="col_heading level0 col2" >Bank of West</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >loan_type</th>
#       <th class="index_name level1" >loan_purpose</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec5f7_level0_row0" class="row_heading level0 row0" rowspan="6">1</th>
#       <th id="T_ec5f7_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_ec5f7_row0_col0" class="data row0 col0" >588,662</td>
#       <td id="T_ec5f7_row0_col1" class="data row0 col1" >676,429</td>
#       <td id="T_ec5f7_row0_col2" class="data row0 col2" >741,250</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_ec5f7_row1_col0" class="data row1 col0" >197,458</td>
#       <td id="T_ec5f7_row1_col1" class="data row1 col1" >103,182</td>
#       <td id="T_ec5f7_row1_col2" class="data row1 col2" >201,250</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_ec5f7_row2_col0" class="data row2 col0" >295,169</td>
#       <td id="T_ec5f7_row2_col1" class="data row2 col1" >147,000</td>
#       <td id="T_ec5f7_row2_col2" class="data row2 col2" >290,490</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row3" class="row_heading level1 row3" >5</th>
#       <td id="T_ec5f7_row3_col0" class="data row3 col0" >356,316</td>
#       <td id="T_ec5f7_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_ec5f7_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row4" class="row_heading level1 row4" >31</th>
#       <td id="T_ec5f7_row4_col0" class="data row4 col0" >459,362</td>
#       <td id="T_ec5f7_row4_col1" class="data row4 col1" >1,115,000</td>
#       <td id="T_ec5f7_row4_col2" class="data row4 col2" >498,333</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row5" class="row_heading level1 row5" >32</th>
#       <td id="T_ec5f7_row5_col0" class="data row5 col0" >436,638</td>
#       <td id="T_ec5f7_row5_col1" class="data row5 col1" >401,667</td>
#       <td id="T_ec5f7_row5_col2" class="data row5 col2" >626,143</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level0_row6" class="row_heading level0 row6" rowspan="6">2</th>
#       <th id="T_ec5f7_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_ec5f7_row6_col0" class="data row6 col0" >361,017</td>
#       <td id="T_ec5f7_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_ec5f7_row6_col2" class="data row6 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_ec5f7_row7_col0" class="data row7 col0" >262,143</td>
#       <td id="T_ec5f7_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_ec5f7_row7_col2" class="data row7 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row8" class="row_heading level1 row8" >4</th>
#       <td id="T_ec5f7_row8_col0" class="data row8 col0" >322,931</td>
#       <td id="T_ec5f7_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_ec5f7_row8_col2" class="data row8 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row9" class="row_heading level1 row9" >5</th>
#       <td id="T_ec5f7_row9_col0" class="data row9 col0" >201,029</td>
#       <td id="T_ec5f7_row9_col1" class="data row9 col1" >nan</td>
#       <td id="T_ec5f7_row9_col2" class="data row9 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row10" class="row_heading level1 row10" >31</th>
#       <td id="T_ec5f7_row10_col0" class="data row10 col0" >310,077</td>
#       <td id="T_ec5f7_row10_col1" class="data row10 col1" >nan</td>
#       <td id="T_ec5f7_row10_col2" class="data row10 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row11" class="row_heading level1 row11" >32</th>
#       <td id="T_ec5f7_row11_col0" class="data row11 col0" >313,517</td>
#       <td id="T_ec5f7_row11_col1" class="data row11 col1" >nan</td>
#       <td id="T_ec5f7_row11_col2" class="data row11 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level0_row12" class="row_heading level0 row12" rowspan="6">3</th>
#       <th id="T_ec5f7_level1_row12" class="row_heading level1 row12" >1</th>
#       <td id="T_ec5f7_row12_col0" class="data row12 col0" >486,595</td>
#       <td id="T_ec5f7_row12_col1" class="data row12 col1" >nan</td>
#       <td id="T_ec5f7_row12_col2" class="data row12 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row13" class="row_heading level1 row13" >2</th>
#       <td id="T_ec5f7_row13_col0" class="data row13 col0" >517,000</td>
#       <td id="T_ec5f7_row13_col1" class="data row13 col1" >nan</td>
#       <td id="T_ec5f7_row13_col2" class="data row13 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row14" class="row_heading level1 row14" >4</th>
#       <td id="T_ec5f7_row14_col0" class="data row14 col0" >406,250</td>
#       <td id="T_ec5f7_row14_col1" class="data row14 col1" >nan</td>
#       <td id="T_ec5f7_row14_col2" class="data row14 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row15" class="row_heading level1 row15" >5</th>
#       <td id="T_ec5f7_row15_col0" class="data row15 col0" >225,000</td>
#       <td id="T_ec5f7_row15_col1" class="data row15 col1" >nan</td>
#       <td id="T_ec5f7_row15_col2" class="data row15 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row16" class="row_heading level1 row16" >31</th>
#       <td id="T_ec5f7_row16_col0" class="data row16 col0" >374,110</td>
#       <td id="T_ec5f7_row16_col1" class="data row16 col1" >nan</td>
#       <td id="T_ec5f7_row16_col2" class="data row16 col2" >485,000</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row17" class="row_heading level1 row17" >32</th>
#       <td id="T_ec5f7_row17_col0" class="data row17 col0" >411,629</td>
#       <td id="T_ec5f7_row17_col1" class="data row17 col1" >nan</td>
#       <td id="T_ec5f7_row17_col2" class="data row17 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level0_row18" class="row_heading level0 row18" rowspan="4">4</th>
#       <th id="T_ec5f7_level1_row18" class="row_heading level1 row18" >1</th>
#       <td id="T_ec5f7_row18_col0" class="data row18 col0" >284,403</td>
#       <td id="T_ec5f7_row18_col1" class="data row18 col1" >nan</td>
#       <td id="T_ec5f7_row18_col2" class="data row18 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row19" class="row_heading level1 row19" >5</th>
#       <td id="T_ec5f7_row19_col0" class="data row19 col0" >95,000</td>
#       <td id="T_ec5f7_row19_col1" class="data row19 col1" >nan</td>
#       <td id="T_ec5f7_row19_col2" class="data row19 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row20" class="row_heading level1 row20" >31</th>
#       <td id="T_ec5f7_row20_col0" class="data row20 col0" >465,909</td>
#       <td id="T_ec5f7_row20_col1" class="data row20 col1" >nan</td>
#       <td id="T_ec5f7_row20_col2" class="data row20 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec5f7_level1_row21" class="row_heading level1 row21" >32</th>
#       <td id="T_ec5f7_row21_col0" class="data row21 col0" >329,286</td>
#       <td id="T_ec5f7_row21_col1" class="data row21 col1" >nan</td>
#       <td id="T_ec5f7_row21_col2" class="data row21 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Avg loan size by product and purpose for approved loans (aggregate)

# %%
hmda.query('action_taken == "Loan Originated"').pivot_table(index=['loant_type', 'loan_purpose'], 
                 columns = ['which_bank'], 
                 values='loan_amount', 
                 aggfunc='mean').style.format('{:,.0f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3a5f7">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >which_bank</th>
#       <th id="T_3a5f7_level0_col0" class="col_heading level0 col0" >All Other Banks</th>
#       <th id="T_3a5f7_level0_col1" class="col_heading level0 col1" >BMO Harris</th>
#       <th id="T_3a5f7_level0_col2" class="col_heading level0 col2" >Bank of West</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >loan_type</th>
#       <th class="index_name level1" >loan_purpose</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a5f7_level0_row0" class="row_heading level0 row0" rowspan="6">1</th>
#       <th id="T_3a5f7_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_3a5f7_row0_col0" class="data row0 col0" >608,791</td>
#       <td id="T_3a5f7_row0_col1" class="data row0 col1" >305,000</td>
#       <td id="T_3a5f7_row0_col2" class="data row0 col2" >799,348</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_3a5f7_row1_col0" class="data row1 col0" >227,032</td>
#       <td id="T_3a5f7_row1_col1" class="data row1 col1" >105,000</td>
#       <td id="T_3a5f7_row1_col2" class="data row1 col2" >203,947</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row2" class="row_heading level1 row2" >4</th>
#       <td id="T_3a5f7_row2_col0" class="data row2 col0" >331,226</td>
#       <td id="T_3a5f7_row2_col1" class="data row2 col1" >176,667</td>
#       <td id="T_3a5f7_row2_col2" class="data row2 col2" >280,758</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row3" class="row_heading level1 row3" >5</th>
#       <td id="T_3a5f7_row3_col0" class="data row3 col0" >715,909</td>
#       <td id="T_3a5f7_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_3a5f7_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row4" class="row_heading level1 row4" >31</th>
#       <td id="T_3a5f7_row4_col0" class="data row4 col0" >463,603</td>
#       <td id="T_3a5f7_row4_col1" class="data row4 col1" >nan</td>
#       <td id="T_3a5f7_row4_col2" class="data row4 col2" >581,154</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row5" class="row_heading level1 row5" >32</th>
#       <td id="T_3a5f7_row5_col0" class="data row5 col0" >451,391</td>
#       <td id="T_3a5f7_row5_col1" class="data row5 col1" >465,000</td>
#       <td id="T_3a5f7_row5_col2" class="data row5 col2" >803,500</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level0_row6" class="row_heading level0 row6" rowspan="5">2</th>
#       <th id="T_3a5f7_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_3a5f7_row6_col0" class="data row6 col0" >369,583</td>
#       <td id="T_3a5f7_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_3a5f7_row6_col2" class="data row6 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_3a5f7_row7_col0" class="data row7 col0" >380,000</td>
#       <td id="T_3a5f7_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_3a5f7_row7_col2" class="data row7 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row8" class="row_heading level1 row8" >4</th>
#       <td id="T_3a5f7_row8_col0" class="data row8 col0" >362,143</td>
#       <td id="T_3a5f7_row8_col1" class="data row8 col1" >nan</td>
#       <td id="T_3a5f7_row8_col2" class="data row8 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row9" class="row_heading level1 row9" >31</th>
#       <td id="T_3a5f7_row9_col0" class="data row9 col0" >320,305</td>
#       <td id="T_3a5f7_row9_col1" class="data row9 col1" >nan</td>
#       <td id="T_3a5f7_row9_col2" class="data row9 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row10" class="row_heading level1 row10" >32</th>
#       <td id="T_3a5f7_row10_col0" class="data row10 col0" >321,653</td>
#       <td id="T_3a5f7_row10_col1" class="data row10 col1" >nan</td>
#       <td id="T_3a5f7_row10_col2" class="data row10 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level0_row11" class="row_heading level0 row11" rowspan="5">3</th>
#       <th id="T_3a5f7_level1_row11" class="row_heading level1 row11" >1</th>
#       <td id="T_3a5f7_row11_col0" class="data row11 col0" >498,166</td>
#       <td id="T_3a5f7_row11_col1" class="data row11 col1" >nan</td>
#       <td id="T_3a5f7_row11_col2" class="data row11 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row12" class="row_heading level1 row12" >2</th>
#       <td id="T_3a5f7_row12_col0" class="data row12 col0" >642,143</td>
#       <td id="T_3a5f7_row12_col1" class="data row12 col1" >nan</td>
#       <td id="T_3a5f7_row12_col2" class="data row12 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row13" class="row_heading level1 row13" >4</th>
#       <td id="T_3a5f7_row13_col0" class="data row13 col0" >595,000</td>
#       <td id="T_3a5f7_row13_col1" class="data row13 col1" >nan</td>
#       <td id="T_3a5f7_row13_col2" class="data row13 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row14" class="row_heading level1 row14" >31</th>
#       <td id="T_3a5f7_row14_col0" class="data row14 col0" >382,264</td>
#       <td id="T_3a5f7_row14_col1" class="data row14 col1" >nan</td>
#       <td id="T_3a5f7_row14_col2" class="data row14 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row15" class="row_heading level1 row15" >32</th>
#       <td id="T_3a5f7_row15_col0" class="data row15 col0" >418,261</td>
#       <td id="T_3a5f7_row15_col1" class="data row15 col1" >nan</td>
#       <td id="T_3a5f7_row15_col2" class="data row15 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level0_row16" class="row_heading level0 row16" rowspan="3">4</th>
#       <th id="T_3a5f7_level1_row16" class="row_heading level1 row16" >1</th>
#       <td id="T_3a5f7_row16_col0" class="data row16 col0" >310,484</td>
#       <td id="T_3a5f7_row16_col1" class="data row16 col1" >nan</td>
#       <td id="T_3a5f7_row16_col2" class="data row16 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row17" class="row_heading level1 row17" >31</th>
#       <td id="T_3a5f7_row17_col0" class="data row17 col0" >242,500</td>
#       <td id="T_3a5f7_row17_col1" class="data row17 col1" >nan</td>
#       <td id="T_3a5f7_row17_col2" class="data row17 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3a5f7_level1_row18" class="row_heading level1 row18" >32</th>
#       <td id="T_3a5f7_row18_col0" class="data row18 col0" >316,667</td>
#       <td id="T_3a5f7_row18_col1" class="data row18 col1" >nan</td>
#       <td id="T_3a5f7_row18_col2" class="data row18 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Rate spread by product and purpose (aggregate)

# %%
hmda.pivot_table(index=['loant_type', 'loan_purpose'],
                 columns = ['which_bank'], 
                 values='rate_spread',
                 aggfunc='mean').style.format('{:,.0f}')

# %% [markdown]
# ## Median income of applicants by product and purpose (aggregate)

# %%
hmda.pivot_table(index=['loant_type', 'loan_purpose'],
                 columns = ['which_bank'], 
                 values='income',
                 aggfunc='median').style.format('{:,.0f}')

# %% [markdown]
# ## Median income of approved loans by product and purpose (aggregate)

# %%
hmda.query('action_taken == "Loan Originated"').pivot_table(index=['loant_type', 'loan_purpose'],
                 columns = ['which_bank'], 
                 values='income', 
                 aggfunc='median').style.format('{:,.0f}')

# %% [markdown]
# ## Table For Minority Analysis

# %%
hmda_vars = ['num_approved_loans', 
             'num_applications',
             'sum_approved_loans',
             'sum_all_loan_amount'
             #'median__all_income',
             #'sum_rate_spread',
             #'mean_LTV'
            ]

# %%
data['pct_minority'] = (data['Tot.Pop'] - data['Tot.WhitePop'])/data['Tot.Pop'] * 100

# %%
data["num_approved_loans"].sum()/data["num_applications"].sum()
# Out:
# 0.8379509596294914

# %%
# finding the median income quintiles
# sort the median__all_income variable in ascending order
data.sort_values(by='pct_minority', inplace=True)

# divide the sorted median__all_income variable into 5 equal parts, or quintiles
data['pct_minority_Quintiles'] = pd.qcut(data['pct_minority'], q=5, labels=False)

# create a new variable called "Median_Income_Quintiles" based on the quintiles
data['pct_minority_Quintiles'] = pd.cut(data['pct_minority'], bins=5, labels=['20', '40', '60', '80', '100'])

# %%
pd.set_option('display.max_rows', 100)

# %%
Quintiles_loan_table = data.groupby('which_bank')[hmda_vars].mean()
Quintiles_loan_table.rename(columns={"num_approved_loans": "mean_num_approved_loans",
                                    "num_applications": "mean_num_applications",
                                    "sum_approved_loans": "mean_sum_approved_loans",
                                    "sum_all_loan_amount": "mean_sum_all_loan_amount"}, inplace= True)
Quintiles_loan_table1=Quintiles_loan_table.round(2)
#Quintiles_loan_table['loan_approvel_rate'] = Quintiles_loan_table['num_approved_loans']/Quintiles_loan_table['num_applications']
#Quintiles_loan_table = Quintiles_loan_table.sort_values(by='loan_approvel_rate', ascending=False)
Quintiles_loan_table1
# Out:
#                  mean_num_approved_loans  mean_num_applications  \
# which_bank
# All Other Banks                    54.40                  64.67
# Bank of West                        2.39                   3.38
#
#                  mean_sum_approved_loans  mean_sum_all_loan_amount
# which_bank
# All Other Banks              25761707.72               29632898.15
# Bank of West                  1312934.44                1767376.67

# %%
Quintiles_loan_table3 = data.groupby(['which_bank', "pct_minority_Quintiles"])[hmda_vars].sum()
Quintiles_loan_table3['loan_pct_in_minority_group'] = Quintiles_loan_table3['num_approved_loans']/Quintiles_loan_table3['num_approved_loans'].groupby("which_bank").sum()
Quintiles_loan_table3['$loan_pct_in_minority_group'] = Quintiles_loan_table3['sum_approved_loans']/Quintiles_loan_table3['sum_approved_loans'].groupby("which_bank").sum()
Quintiles_loan_table3['loan_approval_rate'] = Quintiles_loan_table3['num_approved_loans']/Quintiles_loan_table3['num_applications'].groupby("which_bank").sum()
#Quintiles_loan_table4 = Quintiles_loan_table3.round(2)
Quintiles_loan_table_format = Quintiles_loan_table3.applymap("{:.4f}".format)
Quintiles_loan_table_format.unstack(level=0).iloc[:, -6:]
# Out:
#                        loan_pct_in_minority_group               \
# which_bank                        All Other Banks Bank of West
# pct_minority_Quintiles
# 20                                         0.3182       0.2909
# 40                                         0.3650       0.3513
# 60                                         0.1899       0.1841
# 80                                         0.1015       0.1360
# 100                                        0.0253       0.0377
#
#                        $loan_pct_in_minority_group               \
# which_bank                         All Other Banks Bank of West
# pct_minority_Quintiles
# 20                                          0.3210       0.3268
# 40                                          0.3576       0.3499
# 60                                          0.1896       0.1612
# 80                                          0.1035       0.1229
# 100                                         0.0283       0.0392
#
#                        loan_approval_rate
# which_bank                All Other Banks Bank of West
# pct_minority_Quintiles
# 20                                 0.2677       0.2062
# 40                                 0.3071       0.2490
# 60                                 0.1598       0.1305
# 80                                 0.0854       0.0964
# 100                                0.0213       0.0267

# %%
data['pct_White'] = data['Tot.WhitePop']/data['Tot.Pop'] * 100
data['pct_Black'] = data['Tot.BlackPop ']/data['Tot.Pop'] * 100
data['pct_AmericIndian'] = data['Tot.AmericIndianPop']/data['Tot.Pop'] * 100
data['pct_Asian'] = data['Tot.AsianPop']/data['Tot.Pop'] * 100
data['pct_NativeHawaiianPacific'] = data['Tot.NativeHawaiianPacificPop']/data['Tot.Pop'] * 100
data['pct_OtherRaceAlone'] = data['Tot.OtherRaceAlonePop']/data['Tot.Pop'] * 100
data['pct_TwoOrMoreRace'] = data['Tot.TwoOrMoreRace']/data['Tot.Pop'] * 100
data['pct_TwoOrMoreRace(Some other race)'] = data['Tot.TwoOrMoreRace(Some other race)']/data['Tot.Pop'] * 100
data['pct_Hispanic/Latino'] = data['Tot.Hispanic/Latino']/data['Tot.Pop'] * 100
data['pct_NotHispanic/Latino'] = data['Tot.NotHispanic/Latino']/data['Tot.Pop'] * 100

# %%
data['major_minority'] = data[['pct_Black', 'pct_AmericIndian', 'pct_Asian','pct_NativeHawaiianPacific',
                                        'pct_OtherRaceAlone','pct_TwoOrMoreRace','pct_TwoOrMoreRace(Some other race)',
                                        'pct_Hispanic/Latino']].idxmax(axis=1)
data['major_minority'] = data['major_minority'].apply(lambda x: 'Black' if x=='pct_Black' 
                                                                        else 'American Indian' if x=='pct_AmericIndian' 
                                                                        else 'Asian' if x=='pct_Asian' 
                                                                        else 'Native Hawaiian Pacific' if x=='pct_NativeHawaiianPacific' 
                                                                        else 'Other Race Alone' if x=='pct_OtherRaceAlone' 
                                                                        else 'Two Or More Race' if x=='pct_TwoOrMoreRace' 
                                                                        else 'Two Or More Race(Some other race)' if x=='pct_TwoOrMoreRace(Some other race)' 
                                                                        else 'Hispanic/Latino')

# %%
Quintiles_loan_table4 = data.groupby(['which_bank', "major_minority"])[hmda_vars].sum()
Quintiles_loan_table4['loan_pct_in_minority_group'] = Quintiles_loan_table4['num_approved_loans']/Quintiles_loan_table4['num_approved_loans'].groupby("which_bank").sum()
Quintiles_loan_table4['$loan_pct_in_minority_group'] = Quintiles_loan_table4['sum_approved_loans']/Quintiles_loan_table4['sum_approved_loans'].groupby("which_bank").sum()
Quintiles_loan_table4['loan_approval_rate'] = Quintiles_loan_table4['num_approved_loans']/Quintiles_loan_table4['num_applications']
Quintiles_loan_table5 = Quintiles_loan_table4.applymap("{:.4f}".format)
Quintiles_loan_table5.unstack(level=0).iloc[:, -6:]
# Out:
#                         loan_pct_in_minority_group               \
# which_bank                         All Other Banks Bank of West
# major_minority
# American Indian                             0.0020       0.0027
# Asian                                       0.2344       0.3649
# Black                                       0.0163       0.0179
# Hispanic/Latino                             0.7365       0.5945
# Native Hawaiian Pacific                     0.0000          NaN
# Other Race Alone                            0.0002       0.0011
# Two Or More Race                            0.0105       0.0189
#
#                         $loan_pct_in_minority_group               \
# which_bank                          All Other Banks Bank of West
# major_minority
# American Indian                              0.0012       0.0016
# Asian                                        0.3317       0.4777
# Black                                        0.0163       0.0153
# Hispanic/Latino                              0.6296       0.4709
# Native Hawaiian Pacific                      0.0000          NaN
# Other Race Alone                             0.0004       0.0011
# Two Or More Race                             0.0208       0.0334
#
#                         loan_approval_rate
# which_bank                 All Other Banks Bank of West
# major_minority
# American Indian                     0.8134       0.6304
# Asian                               0.8804       0.6989
# Black                               0.8206       0.7423
# Hispanic/Latino                     0.8297       0.7143
# Native Hawaiian Pacific             0.9000          NaN
# Other Race Alone                    0.8000       0.6316
# Two Or More Race                    0.8590       0.7108

# %%
# 18.9% is the national average for hispanic/latino population
# Here, we consider anything over the national average of 18.9% a high hispanic population
# Hispanic pop in AZ = 32.3%, in CA = 39.4%
data['high_hisp_pop'] = ((data['Tot.Hispanic/Latino']/data['Tot.Pop']) > 0.189)
high_hispanic= data[data['high_hisp_pop']]

# %%
# finding the median income quintiles
# sort the median__all_income variable in ascending order
data.sort_values(by='median_all_income', inplace=True)

# divide the sorted median__all_income variable into 5 equal parts, or quintiles
data['Median_Income_Quintiles'] = pd.qcut(data['median_all_income'], q=5, labels=False)

# create a new variable called "Median_Income_Quintiles" based on the quintiles
data['Median_Income_Quintiles'] = pd.cut(data['Median_Income_Quintiles'], bins=5, labels=['Q1', 'Q2', 'Q3', 'Q4', 'Q5'])

# %%
Quintiles_loan_table = data.groupby(['which_bank', 'Median_Income_Quintiles'])[hmda_vars].mean()
Quintiles_loan_table['loan_approvel_rate'] = Quintiles_loan_table['num_approved_loans']/Quintiles_loan_table['num_applications']
Quintiles_loan_table = Quintiles_loan_table.sort_values(by='loan_approvel_rate', ascending=False)
Quintiles_loan_table6 = Quintiles_loan_table.applymap("{:.4f}".format)
Quintiles_loan_table6.unstack(level=0).iloc[:, -6:]
# Out:
#                         sum_approved_loans               sum_all_loan_amount  \
# which_bank                 All Other Banks  Bank of West     All Other Banks
# Median_Income_Quintiles
# Q1                           10128921.7557   392848.2972       12360877.8626
# Q2                           16314506.1447   640114.4165       19548306.7820
# Q3                           23985798.9810   654829.1367       27932552.1075
# Q4                           33023309.4145  1069563.7950       37655206.6590
# Q5                           65560580.6738  2429919.7174       72451236.7021
#
#                                       loan_approvel_rate
# which_bank               Bank of West    All Other Banks Bank of West
# Median_Income_Quintiles
# Q1                        583684.2105             0.8017       0.6509
# Q2                        882757.4371             0.8181       0.6734
# Q3                        940989.2086             0.8423       0.6826
# Q4                       1450512.5409             0.8678       0.7071
# Q5                       3258275.5299             0.8895       0.7206
