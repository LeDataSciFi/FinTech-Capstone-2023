# %%
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from census import Census
from us import states

# %%
c = Census("a82acbcf878654f6da6b3139274b90ff160b8120")

# %%
az_census = c.acs5.state_county_tract(fields = ('NAME', 'C17002_001E', 'C17002_002E', 'C17002_003E', 'B01003_001E'),
                                      state_fips = states.AZ.fips,
                                      county_fips = "*",
                                      tract = "*",
                                      year = 2020)

# %%
az_df = pd.DataFrame(az_census)

# %%
print(az_df)
# Out:
#                                                NAME  C17002_001E  C17002_002E  \
# 0     Census Tract 610.44, Maricopa County, Arizona       8773.0         71.0
# 1     Census Tract 610.45, Maricopa County, Arizona       7790.0         77.0
# 2     Census Tract 610.46, Maricopa County, Arizona       6032.0        487.0
# 3     Census Tract 610.47, Maricopa County, Arizona       4194.0         60.0
# 4     Census Tract 610.48, Maricopa County, Arizona       3816.0          0.0
# ...                                             ...          ...          ...
# 1760    Census Tract 15.01, Yavapai County, Arizona       2562.0         45.0
# 1761    Census Tract 15.02, Yavapai County, Arizona       4607.0        238.0
# 1762    Census Tract 16.01, Yavapai County, Arizona       6046.0        897.0
# 1763    Census Tract 16.02, Yavapai County, Arizona       3825.0        271.0
# 1764    Census Tract 16.04, Yavapai County, Arizona       1199.0         13.0
#
# ...

# %%
az_census = c.acs5.state_county_tract(fields = ('NAME', 'C17002_001E', 'C17002_002E', 'C17002_003E', 'B01003_001E', 'B02001_002E'),
                                      state_fips = states.AZ.fips,
                                      county_fips = "*",
                                      tract = "*",
                                      year = 2020)

# %%
print(az_census)
# Out:
# [{'NAME': 'Census Tract 610.44, Maricopa County, Arizona', 'C17002_001E': 8773.0, 'C17002_002E': 71.0, 'C17002_003E': 335.0, 'B01003_001E': 8773.0, 'B02001_002E': 6733.0, 'state': '04', 'county': '013', 'tract': '061044'}, {'NAME': 'Census Tract 610.45, Maricopa County, Arizona', 'C17002_001E': 7790.0, 'C17002_002E': 77.0, 'C17002_003E': 106.0, 'B01003_001E': 7874.0, 'B02001_002E': 6265.0, 'state': '04', 'county': '013', 'tract': '061045'}, {'NAME': 'Census Tract 610.46, Maricopa County, Arizona', 'C17002_001E': 6032.0, 'C17002_002E': 487.0, 'C17002_003E': 329.0, 'B01003_001E': 6060.0, 'B02001_002E': 4002.0, 'state': '04', 'county': '013', 'tract': '061046'}, {'NAME': 'Census Tract 610.47, Maricopa County, Arizona', 'C17002_001E': 4194.0, 'C17002_002E': 60.0, 'C17002_003E': 106.0, 'B01003_001E': 4195.0, 'B02001_002E': 2705.0, 'state': '04', 'county': '013', 'tract': '061047'}, {'NAME': 'Census Tract 610.48, Maricopa County, Arizona', 'C17002_001E': 3816.0, 'C17002_002E': 0.0, 'C17002
# ...

# %%
az_df = pd.DataFrame(az_census)

# %%
print(az_df)
# Out:
#                                                NAME  C17002_001E  C17002_002E  \
# 0     Census Tract 610.44, Maricopa County, Arizona       8773.0         71.0
# 1     Census Tract 610.45, Maricopa County, Arizona       7790.0         77.0
# 2     Census Tract 610.46, Maricopa County, Arizona       6032.0        487.0
# 3     Census Tract 610.47, Maricopa County, Arizona       4194.0         60.0
# 4     Census Tract 610.48, Maricopa County, Arizona       3816.0          0.0
# ...                                             ...          ...          ...
# 1760    Census Tract 15.01, Yavapai County, Arizona       2562.0         45.0
# 1761    Census Tract 15.02, Yavapai County, Arizona       4607.0        238.0
# 1762    Census Tract 16.01, Yavapai County, Arizona       6046.0        897.0
# 1763    Census Tract 16.02, Yavapai County, Arizona       3825.0        271.0
# 1764    Census Tract 16.04, Yavapai County, Arizona       1199.0         13.0
#
# ...

# %%
print(az_df.head(2))
print('Shape: ', az_df.shape)
# Out:
#                                             NAME  C17002_001E  C17002_002E  \
# 0  Census Tract 610.44, Maricopa County, Arizona       8773.0         71.0
# 1  Census Tract 610.45, Maricopa County, Arizona       7790.0         77.0
#
#    C17002_003E  B01003_001E  B02001_002E state county   tract
# 0        335.0       8773.0       6733.0    04    013  061044
# 1        106.0       7874.0       6265.0    04    013  061045
# Shape:  (1765, 9)

# %%
az_tract = gpd.read_file("https://www2.census.gov/geo/tiger/TIGER2020/TRACT/tl_2020_04_tract.zip")

# %%
az_tract = az_tract.to_crs(epsg = 32617)

# %%
print(az_tract.head(2))
print('Shape: ', az_tract.shape)
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID  NAME           NAMELSAD  MTFCC  \
# 0      04      015  950500  04015950500  9505  Census Tract 9505  G5020
# 1      04      015  954900  04015954900  9549  Census Tract 9549  G5020
#
#   FUNCSTAT       ALAND    AWATER     INTPTLAT      INTPTLON  \
# 0        S  1255016476  39469850  +35.3440369  -114.3629894
# 1        S    22392503         0  +35.2440284  -114.0595108
#
#                                             geometry
# 0  POLYGON ((-2605753.221 4497432.366, -2605733.2...
# 1  POLYGON ((-2561412.583 4449714.181, -2561223.1...
# Shape:  (1765, 13)

# %%
print("\nThe shapefile projection is: {}".format(az_tract.crs))
# Out:
# The shapefile projection is: EPSG:32617

# %%
az_df["GEOID"] = az_df["state"] + az_df["county"] + az_df["tract"]

# %%
az_df.head(2)
# Out:
#                                             NAME  C17002_001E  C17002_002E  \
# 0  Census Tract 610.44, Maricopa County, Arizona       8773.0         71.0
# 1  Census Tract 610.45, Maricopa County, Arizona       7790.0         77.0
#
#    C17002_003E  B01003_001E  B02001_002E state county   tract        GEOID
# 0        335.0       8773.0       6733.0    04    013  061044  04013061044
# 1        106.0       7874.0       6265.0    04    013  061045  04013061045

# %%
az_df = az_df.drop(columns = ["state", "county"])

# %%
az_df.head(2)
# Out:
#                                             NAME  C17002_001E  C17002_002E  \
# 0  Census Tract 610.44, Maricopa County, Arizona       8773.0         71.0
# 1  Census Tract 610.45, Maricopa County, Arizona       7790.0         77.0
#
#    C17002_003E  B01003_001E  B02001_002E   tract        GEOID
# 0        335.0       8773.0       6733.0  061044  04013061044
# 1        106.0       7874.0       6265.0  061045  04013061045

# %%
az_df.head(4)
# Out:
#                                             NAME  C17002_001E  C17002_002E  \
# 0  Census Tract 610.44, Maricopa County, Arizona       8773.0         71.0
# 1  Census Tract 610.45, Maricopa County, Arizona       7790.0         77.0
# 2  Census Tract 610.46, Maricopa County, Arizona       6032.0        487.0
# 3  Census Tract 610.47, Maricopa County, Arizona       4194.0         60.0
#
#    C17002_003E  B01003_001E  B02001_002E   tract        GEOID
# 0        335.0       8773.0       6733.0  061044  04013061044
# 1        106.0       7874.0       6265.0  061045  04013061045
# 2        329.0       6060.0       4002.0  061046  04013061046
# 3        106.0       4195.0       2705.0  061047  04013061047

# %%
print("Column data types for census data:\n{}".format(az_df.dtypes))
# Out:
# Column data types for census data:
# NAME            object
# C17002_001E    float64
# C17002_002E    float64
# C17002_003E    float64
# B01003_001E    float64
# B02001_002E    float64
# tract           object
# GEOID           object
# dtype: object

# %%
print("\nColumn data types for census shapefile:\n{}".format(az_tract.dtypes))
# Out:
# Column data types for census shapefile:
# STATEFP       object
# COUNTYFP      object
# TRACTCE       object
# GEOID         object
# NAME          object
# NAMELSAD      object
# MTFCC         object
# FUNCSTAT      object
# ALAND          int64
# AWATER         int64
# INTPTLAT      object
# INTPTLON      object
# geometry    geometry
# dtype: object

# %%
az_merge = az_tract.merge(az_df, on = "GEOID")

# %%
print(az_merge.head(2))
print('Shape: ', az_merge.shape)
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID NAME_x           NAMELSAD  MTFCC  \
# 0      04      015  950500  04015950500   9505  Census Tract 9505  G5020
# 1      04      015  954900  04015954900   9549  Census Tract 9549  G5020
#
#   FUNCSTAT       ALAND    AWATER     INTPTLAT      INTPTLON  \
# 0        S  1255016476  39469850  +35.3440369  -114.3629894
# 1        S    22392503         0  +35.2440284  -114.0595108
#
#                                             geometry  \
# 0  POLYGON ((-2605753.221 4497432.366, -2605733.2...
# 1  POLYGON ((-2561412.583 4449714.181, -2561223.1...
#
#                                       NAME_y  C17002_001E  C17002_002E  \
# 0  Census Tract 9505, Mohave County, Arizona       1589.0         97.0
# 1  Census Tract 9549, Mohave County, Arizona       3660.0        163.0
#
#    C17002_003E  B01003_001E  B02001_002E   tract
# 0        248.0       1601.0       1455.0  950500
# 1        338.0       3662.0       3460.0  954900
# Shape:  (1765, 20)

# %%
az_poverty_tract = az_merge[["STATEFP", "COUNTYFP", "TRACTCE", "GEOID", "geometry", "C17002_001E", "C17002_002E", "C17002_003E", "B01003_001E", "B02001_002E"]]

# %%
az_minority_tract = az_merge[["STATEFP", "COUNTYFP", "TRACTCE", "GEOID", "geometry", "C17002_001E", "C17002_002E", "C17002_003E", "B01003_001E", "B02001_002E"]]

# %%
print(az_minority_tract.head(2))
print('Shape: ', az_minority_tract.shape)
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID  \
# 0      04      015  950500  04015950500
# 1      04      015  954900  04015954900
#
#                                             geometry  C17002_001E  \
# 0  POLYGON ((-2605753.221 4497432.366, -2605733.2...       1589.0
# 1  POLYGON ((-2561412.583 4449714.181, -2561223.1...       3660.0
#
#    C17002_002E  C17002_003E  B01003_001E  B02001_002E
# 0         97.0        248.0       1601.0       1455.0
# 1        163.0        338.0       3662.0       3460.0
# Shape:  (1765, 10)

# %%
az_poverty_county = az_poverty_tract.dissolve(by = 'TRACTCE', aggfunc = 'sum')

# %%
az_minority_county = az_poverty_tract.dissolve(by = 'TRACTCE', aggfunc = 'sum')

# %%
print(az_minority_county.head(2))
print('Shape: ', az_minority_county.shape)
# Out:
#                                                   geometry  C17002_001E  \
# TRACTCE
# 000100   MULTIPOLYGON (((-2378471.259 3990141.157, -237...       8797.0
# 000101   POLYGON ((-2254947.957 3965119.134, -2254903.4...       1123.0
#
#          C17002_002E  C17002_003E  B01003_001E  B02001_002E
# TRACTCE
# 000100         845.0        655.0       9256.0       7811.0
# 000101          82.0         33.0       1123.0       1095.0
# Shape:  (1642, 6)

# %%
az_minority_county["White_Rate"] = (az_poverty_county["B02001_002E"]) / az_poverty_county["B01003_001E"] * 100

# %%
az_minority_county["White_Rate"] = (az_minority_county["B02001_002E"]) / az_minority_county["B01003_001E"] * 100

# %%
az_minority_county.head(5)
# Out:
#                                                   geometry  C17002_001E  \
# TRACTCE
# 000100   MULTIPOLYGON (((-2378471.259 3990141.157, -237...       8797.0
# 000101   POLYGON ((-2254947.957 3965119.134, -2254903.4...       1123.0
# 000102   POLYGON ((-2255594.069 3964324.754, -2255494.9...        726.0
# 000200   MULTIPOLYGON (((-2380283.592 3992046.324, -238...      13684.0
# 000201   MULTIPOLYGON (((-2298192.355 3959966.468, -229...       8829.0
#
#          C17002_002E  C17002_003E  B01003_001E  B02001_002E  White_Rate
# TRACTCE
# 000100         845.0        655.0       9256.0       7811.0   84.388505
# 000101          82.0         33.0       1123.0       1095.0   97.506679
# 000102          52.0         54.0        728.0        693.0   95.192308
# 000200         799.0       1732.0      13854.0      10168.0   73.393966
# 000201         283.0        440.0       8853.0       7973.0   90.059867

# %%
fig, ax = plt.subplots(1, 1, figsize = (20, 10))

# Plot data
# Source: https://geopandas.readthedocs.io/en/latest/docs/user_guide/mapping.html
az_minority_county.plot(column = "White_Rate",
                       ax = ax,
                       cmap = "RdPu",
                       legend = True)

# Stylize plots
plt.style.use('bmh')

# Set title
ax.set_title('White Rates (%) in Arizona', fontdict = {'fontsize': '25', 'fontweight' : '3'})
# Out:
# Text(0.5, 1.0, 'White Rates (%) in Arizona')

# %%
less_than_50_pct_white = az_minority_county["White_Rate"] < 50]
# Out:
#   File "<ipython-input-35-ce7711607a0c>", line 1
#     less_than_50_pct_white = az_minority_county["White_Rate"] < 50]
#                                                                   ^
# SyntaxError: unmatched ']'

# %%
less_than_50_pct_white = az_minority_county["White_Rate"] < 50

# %%
fig, ax = plt.subplots(1, 1, figsize = (20, 10))

# Plot data
# Source: https://geopandas.readthedocs.io/en/latest/docs/user_guide/mapping.html
az_minority_county.plot(column = "White_Rate",
                       ax = ax,
                       cmap = "RdPu",
                       legend = True)

# Stylize plots
plt.style.use('bmh')

# Set title
ax.set_title('White Rates (%) in Arizona', fontdict = {'fontsize': '25', 'fontweight' : '3'})
